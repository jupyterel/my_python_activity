# %%
import numpy as np
import pandas as pd

# %%
# Read the CSV file with Pandas
platforms = pd.read_csv('ott.csv')

# View the DataFrame
platforms
# Out:
#           ID  Netflix  Hulu  Prime Video  Disney+
# 0          1        0     0            1        0
# 1          2        0     1            0        0
# 2          3        0     0            1        0
# 3          4        1     0            0        0
# 4          5        0     0            1        0
# ...      ...      ...   ...          ...      ...
# 16739  16740        0     0            1        0
# 16740  16741        0     0            1        0
# 16741  16742        0     0            1        0
# 16742  16743        0     0            1        0
# 16743  16744        1     0            0        0
#
# [16744 rows x 5 columns]

# %%
print(platforms.shape)
print(platforms.head())
print(platforms.tail())
print(platforms.dtypes)
# Out:
# (16744, 5)
#    ID  Netflix  Hulu  Prime Video  Disney+
# 0   1        0     0            1        0
# 1   2        0     1            0        0
# 2   3        0     0            1        0
# 3   4        1     0            0        0
# 4   5        0     0            1        0
#           ID  Netflix  Hulu  Prime Video  Disney+
# 16739  16740        0     0            1        0
# 16740  16741        0     0            1        0
# 16741  16742        0     0            1        0
# 16742  16743        0     0            1        0
# 16743  16744        1     0            0        0
# ID             int64
# Netflix        int64
# Hulu           int64
# Prime Video    int64
# Disney+        int64
# dtype: object

# %%
films = pd.read_excel('movies.xlsx')

films
# Out:
#                                 Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010  13+   8.8             0.87
# 1                          The Matrix  1999  18+   8.7             0.87
# 2              Avengers: Infinity War  2018  13+   8.5             0.84
# 3                  Back to the Future  1985   7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966  18+   8.8             0.97
# ...                               ...   ...  ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  NaN   6.2              NaN
# 16740                  The Poof Point  2001   7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  NaN   5.7              NaN
# 16742              Man Among Cheetahs  2017  NaN   6.6              NaN
# 16743                In Beaver Valley  1950  NaN   NaN              NaN
#
#                             Directors                            Genres  \
# ...

# %%
print(films.shape)
print(films.head())
print(films.tail())
print(films.dtypes)
# Out:
# (16744, 10)
#                             Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0                       Inception  2010  13+   8.8             0.87
# 1                      The Matrix  1999  18+   8.7             0.87
# 2          Avengers: Infinity War  2018  13+   8.5             0.84
# 3              Back to the Future  1985   7+   8.5             0.96
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             0.97
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# ...

# %%
films['Age'].isnull().sum()
# Out:
# 9390

# %%
films['Age'].fillna('Others', inplace=True)

films
# Out:
#                                 Title  Year     Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010     13+   8.8             0.87
# 1                          The Matrix  1999     18+   8.7             0.87
# 2              Avengers: Infinity War  2018     13+   8.5             0.84
# 3                  Back to the Future  1985      7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966     18+   8.8             0.97
# ...                               ...   ...     ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  Others   6.2              NaN
# 16740                  The Poof Point  2001      7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  Others   5.7              NaN
# 16742              Man Among Cheetahs  2017  Others   6.6              NaN
# 16743                In Beaver Valley  1950  Others   NaN              NaN
#
# ...

# %%
films['Directors'].isnull().sum()
# Out:
# 726

# %%
films['Directors'].fillna('Others', inplace=True)

films
# Out:
#                                 Title  Year     Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010     13+   8.8             0.87
# 1                          The Matrix  1999     18+   8.7             0.87
# 2              Avengers: Infinity War  2018     13+   8.5             0.84
# 3                  Back to the Future  1985      7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966     18+   8.8             0.97
# ...                               ...   ...     ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  Others   6.2              NaN
# 16740                  The Poof Point  2001      7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  Others   5.7              NaN
# 16742              Man Among Cheetahs  2017  Others   6.6              NaN
# 16743                In Beaver Valley  1950  Others   NaN              NaN
#
# ...

# %%
films['Genres'].isnull().sum()
# Out:
# 275

# %%
films['Genres'].fillna('Others', inplace=True)

films
# Out:
#                                 Title  Year     Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010     13+   8.8             0.87
# 1                          The Matrix  1999     18+   8.7             0.87
# 2              Avengers: Infinity War  2018     13+   8.5             0.84
# 3                  Back to the Future  1985      7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966     18+   8.8             0.97
# ...                               ...   ...     ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  Others   6.2              NaN
# 16740                  The Poof Point  2001      7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  Others   5.7              NaN
# 16742              Man Among Cheetahs  2017  Others   6.6              NaN
# 16743                In Beaver Valley  1950  Others   NaN              NaN
#
# ...

# %%
films['Country'].isnull().sum()
# Out:
# 435

# %%
films['Country'].fillna('Others', inplace=True)

films
# Out:
#                                 Title  Year     Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010     13+   8.8             0.87
# 1                          The Matrix  1999     18+   8.7             0.87
# 2              Avengers: Infinity War  2018     13+   8.5             0.84
# 3                  Back to the Future  1985      7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966     18+   8.8             0.97
# ...                               ...   ...     ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  Others   6.2              NaN
# 16740                  The Poof Point  2001      7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  Others   5.7              NaN
# 16742              Man Among Cheetahs  2017  Others   6.6              NaN
# 16743                In Beaver Valley  1950  Others   NaN              NaN
#
# ...

# %%
films['Language'].isnull().sum()
# Out:
# 599

# %%
films['Language'].fillna('Others', inplace=True)

films
# Out:
#                                 Title  Year     Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010     13+   8.8             0.87
# 1                          The Matrix  1999     18+   8.7             0.87
# 2              Avengers: Infinity War  2018     13+   8.5             0.84
# 3                  Back to the Future  1985      7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966     18+   8.8             0.97
# ...                               ...   ...     ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  Others   6.2              NaN
# 16740                  The Poof Point  2001      7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  Others   5.7              NaN
# 16742              Man Among Cheetahs  2017  Others   6.6              NaN
# 16743                In Beaver Valley  1950  Others   NaN              NaN
#
# ...

# %%
print(films.dtypes)
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes    float64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %%
# Here my data type is float 64, I receive an error when running the snippet as it cannot turn float into int
# I also believe that in this case float is the right data type

# films['Rotten Tomatoes'] = films['Rotten Tomatoes'].astype(object).astype(int)

# print(films.dtypes)

# %%
films['IMDb'].isnull().sum()
# Out:
# 571

# %%
films['IMDb'].fillna(films['IMDb'].mean(), inplace=True)

films
# Out:
#                                 Title  Year     Age      IMDb  \
# 0                           Inception  2010     13+  8.800000
# 1                          The Matrix  1999     18+  8.700000
# 2              Avengers: Infinity War  2018     13+  8.500000
# 3                  Back to the Future  1985      7+  8.500000
# 4      The Good, the Bad and the Ugly  1966     18+  8.800000
# ...                               ...   ...     ...       ...
# 16739       The Ghosts of Buxley Hall  1980  Others  6.200000
# 16740                  The Poof Point  2001      7+  4.700000
# 16741           Sharks of Lost Island  2013  Others  5.700000
# 16742              Man Among Cheetahs  2017  Others  6.600000
# 16743                In Beaver Valley  1950  Others  5.902751
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
films['IMDb'].isnull().sum()
# Out:
# 0

# %%
films['Rotten Tomatoes'].isnull().sum()
# Out:
# 11586

# %%
films['Rotten Tomatoes'].fillna(films['Rotten Tomatoes'].mean(), inplace=True)

films
# Out:
#                                 Title  Year     Age      IMDb  \
# 0                           Inception  2010     13+  8.800000
# 1                          The Matrix  1999     18+  8.700000
# 2              Avengers: Infinity War  2018     13+  8.500000
# 3                  Back to the Future  1985      7+  8.500000
# 4      The Good, the Bad and the Ugly  1966     18+  8.800000
# ...                               ...   ...     ...       ...
# 16739       The Ghosts of Buxley Hall  1980  Others  6.200000
# 16740                  The Poof Point  2001      7+  4.700000
# 16741           Sharks of Lost Island  2013  Others  5.700000
# 16742              Man Among Cheetahs  2017  Others  6.600000
# 16743                In Beaver Valley  1950  Others  5.902751
#
#        Rotten Tomatoes                       Directors  \
# 0             0.870000               Christopher Nolan
# 1             0.870000  Lana Wachowski,Lilly Wachowski
# ...

# %%
films['Rotten Tomatoes'].isnull().sum()
# Out:
# 0
