# %%
# Copy the YAML file and your Twitter keys over before you start to work.
import yaml
from yaml.loader import SafeLoader
from twitter import *

# Import the YAML file - remember to specify the whole path.
twitter_creds = yaml.safe_load(open('twitter_tmp.yaml', 'r').read())

# Pass your twitter credentials.
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))

# %%
# Confirm your connection.
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f80ebd88940>

# %%
# Run a test with #python. Python load 120 tweets at a time
python_tweets = twitter_api.search.tweets(q='#python')

# View output.
print(python_tweets)
# Out:
# {'statuses': [{'created_at': 'Fri Jul 01 18:24:44 +0000 2022', 'id': 1542937263075721216, 'id_str': '1542937263075721216', 'text': 'RT @GalaxyKiiara: Screenshot Me Streaming #C\nShared⬇️ keep you word @KIIARA\nLink To Closer⬇️#kiiara #Ad #AI \nhttps://t.co/TDGtWpKy2d #Pytho…', 'truncated': False, 'entities': {'hashtags': [{'text': 'C', 'indices': [42, 44]}, {'text': 'kiiara', 'indices': [92, 99]}, {'text': 'Ad', 'indices': [100, 103]}, {'text': 'AI', 'indices': [104, 107]}], 'symbols': [], 'user_mentions': [{'screen_name': 'GalaxyKiiara', 'name': '\uf8ff KIIARA.galaxy', 'id': 1349740197882322944, 'id_str': '1349740197882322944', 'indices': [3, 16]}, {'screen_name': 'KIIARA', 'name': 'kiiara', 'id': 3230265991, 'id_str': '3230265991', 'indices': [68, 75]}], 'urls': [{'url': 'https://t.co/TDGtWpKy2d', 'expanded_url': 'https://soundcloud.app.goo.gl/PCFGM4P1a8gRAazf7', 'display_url': 'soundcloud.app.goo.gl/PCFGM4P1a8gRAa…', 'indices': [109, 132]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1095125727421366274, 'id_str': '1095125727421366274', 'name': '\uf8ff𝓜𝕖𝕟𝕤𝕥𝕣𝕒𝕦𝕝 𝓜𝕒𝕥𝕙𝕖𝕣𝕤', 'screen_name': 'MenstraulM', 'location': 'Tampax', 'description': "still don't give no fucks", 'url': 'https://t.co/NG1kbOlsD7', 'entities': {'url': {'urls': [{'url': 'https://t.co/NG1kbOlsD7', 'expanded_url': 'https://instagram.com/menstraul.mathers?igshid=ripl53zu1dz2', 'display_url': 'instagram.com/menstraul.math…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 219, 'friends_count': 6, 'listed_count': 4, 'created_at': 'Tue Feb 12 01:01:34 +0000 2019', 'favourites_count': 30729, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 25514, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1487102948073254919/NBSZqPWT_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1487102948073254919/NBSZqPWT_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1095125727421366274/1624928640', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Jan 18 18:11:05 +0000 2022', 'id': 1483502219790061571, 'id_str': '1483502219790061571', 'text': 'Screenshot Me Streaming #C\nShared⬇️ keep you word @KIIARA\nLink To Closer⬇️#kiiara #Ad #AI \nhttps://t.co/TDGtWpKy2d… https://t.co/fudf2A9LIL', 'truncated': True, 'entities': {'hashtags': [{'text': 'C', 'indices': [24, 26]}, {'text': 'kiiara', 'indices': [74, 81]}, {'text': 'Ad', 'indices': [82, 85]}, {'text': 'AI', 'indices': [86, 89]}], 'symbols': [], 'user_mentions': [{'screen_name': 'KIIARA', 'name': 'kiiara', 'id': 3230265991, 'id_str': '3230265991', 'indices': [50, 57]}], 'urls': [{'url': 'https://t.co/TDGtWpKy2d', 'expanded_url': 'https://soundcloud.app.goo.gl/PCFGM4P1a8gRAazf7', 'display_url': 'soundcloud.app.goo.gl/PCFGM4P1a8gRAa…', 'indices': [91, 114]}, {'url': 'https://t.co/fudf2A9LIL', 'expanded_url': 'https://twitter.com/i/web/status/1483502219790061571', 'display_url': 'twitter.co ...

# %%
# Identify worldwide trends.
trends_worldwide = twitter_api.trends.available()

# How many trends are available.
print(len(trends_worldwide))

# Example of trends_worldwide.
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %%
# Write a Twitter request.
list_of_names = [_['name'] for _ in trends_worldwide]

# List of first 10 cities.
list_of_names[0:10]
# Out:
# ['Worldwide',
#  'Winnipeg',
#  'Ottawa',
#  'Quebec',
#  'Montreal',
#  'Toronto',
#  'Edmonton',
#  'Calgary',
#  'Vancouver',
#  'Birmingham']

# %%
# Find New York.
US = 'New York'

# Create a variable.
new_york = [_ for _ in trends_worldwide if _['name'] == US]

# View the output.
print(len(new_york))

# Use index to find New York.
new_york[0]
# Out:
# 1
# {'name': 'New York',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/2459115',
#  'parentid': 23424977,
#  'country': 'United States',
#  'woeid': 2459115,
#  'countryCode': 'US'}

# %%
# List of 'where on earth identifiers' (woeid).
new_york[0]['woeid']
# Out:
# 2459115

# %%
# Find London.
UK = 'London'

# Create a variable.
london = [_ for _ in trends_worldwide if _['name'] == UK]

# View the output.
print(len(london))

# Use index to find New York.
london[0]
# Out:
# 1
# {'name': 'London',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/44418',
#  'parentid': 23424975,
#  'country': 'United Kingdom',
#  'woeid': 44418,
#  'countryCode': 'GB'}

# %%
# List of 'where on earth identifiers' (woeid).
london[0]['woeid']
# Out:
# 44418

# %%
# Look at common trends in New York.
new_york_trends = twitter_api.trends.place(_id = new_york[0]['woeid'])

# View the output.
new_york_trends
# Out:
# [{'trends': [{'name': '#TheChi',
#     'url': 'http://twitter.com/search?q=%23TheChi',
#     'promoted_content': None,
#     'query': '%23TheChi',
#     'tweet_volume': 32650},
#    {'name': 'Bruce Brown',
#     'url': 'http://twitter.com/search?q=%22Bruce+Brown%22',
#     'promoted_content': None,
#     'query': '%22Bruce+Brown%22',
#     'tweet_volume': None},
#    {'name': 'Utah',
#     'url': 'http://twitter.com/search?q=Utah',
#     'promoted_content': None,
#     'query': 'Utah',
#     'tweet_volume': 36519},
#    {'name': 'Mitch',
#     'url': 'http://twitter.com/search?q=Mitch',
#     'promoted_content': None,
#     'query': 'Mitch',
#     'tweet_volume': 173069},
#    {'name': 'Canadians',
#     'url': 'http://twitter.com/search?q=Canadians',
#     'promoted_content': None,
#     'query': 'Canadians',
#     'tweet_volume': 38954},
#    {'name': 'Eddie',
#     'url': 'http://twitter.com/search?q=Eddie',
#     'promoted_content': None,
#     'query': 'Eddie',
#     'tweet_volume': 362105},
#    {'name': "They're a 10",
#     'url': 'http://twitter.com/search?q=%22They%27re+a+10%22',
#     'promoted_content': None,
#     'query': '%22They%27re+a+10%22',
#     'tweet_volume': 19395},
#    {'name': 'Miles Bridges',
#     'url': 'http://twitter.com/search?q=%22Miles+Bridges%22',
#     'promoted_content': None,
#     'query': '%22Miles+Bridges%22',
#     'tweet_volume': 43375},
#    {'name': '#TheBoys',
#     'url': 'http://twitter.com/search?q=%23TheBoys',
#     'promoted_content': None,
#     'query': '%23TheBoys',
#     'tweet_volume': 53405},
#    {'name': 'Zion',
#     'url': 'http://twitter.com/search?q=Zion',
#     'promoted_content': None,
#     'query': 'Zion',
#     'tweet_volume': 27629},
#    {'name': '#UFC276',
#     'url': 'http://twitter.com/search?q=%23UFC276',
#     'promoted_content': None,
#     'query': '%23UFC276',
#     'tweet_volume': 22495},
#    {'name': 'Brogdon',
#     'url': 'http://twitter.com/search?q=Brogdon',
#     'promoted_content': None,
#     'query': 'Brogdon',
#     'tweet_volume': 27873},
#    {'name': 'Canada',
#     'url': 'http://twitter.com/search?q=Canada',
#     'promoted_content': None,
#     'query': 'Canada',
#     'tweet_volume': 368247},
#    {'name': '#samsummerfridays',
#     'url': 'http://twitter.com/search?q=%23samsummerfridays',
#     'promoted_content': None,
#     'query': '%23samsummerfridays',
#     'tweet_volume': None},
#    {'name': 'Brad Stevens',
#     'url': 'http://twitter.com/search?q=%22Brad+Stevens%22',
#     'promoted_content': None,
#     'query': '%22Brad+Stevens%22',
#     'tweet_volume': None},
#    {'name': 'Pacers',
#     'url': 'http://twitter.com/search?q=Pacers',
#     'promoted_content': None,
#     'query': 'Pacers',
#     'tweet_volume': 18358},
#    {'name': '#freecodefridaycontest',
#     'url': 'http://twitter.com/search?q=%23freecodefridaycontest',
#     'promoted_content': None,
#     'query': '%23freecodefridaycontest',
#     'tweet_volume': None},
#    {'name': 'Bobby Bonilla',
#     'url': 'http://twitter.com/search?q=%22Bobby+Bonilla%22',
#     'promoted_content': None,
#     'query': '%22Bobby+Bonilla%22',
#     'tweet_volume': 26938},
#    {'name': 'Wyoming',
#     'url': 'http://twitter.com/search?q=Wyoming',
#     'promoted_content': None,
#     'query': 'Wyoming',
#     'tweet_volume': 42765},
#    {'name': 'Theis',
#     'url': 'http://twitter.com/search?q=Theis',
#     'promoted_content': None,
#     'query': 'Theis',
#     'tweet_volume': None},
#    {'name': '4th of July',
#     'url': 'http://twitter.com/search?q=%224th+of+July%22',
#     'promoted_content': None,
#     'query': '%224th+of+July%22',
#     'tweet_volume': 91055},
#    {'name': 'Liz Cheney',
#     'url': 'http://twitter.com/search?q=%22Liz+Cheney%22',
#     'promoted_content': None,
#     'query': '%22Liz+Cheney%22',
#     'tweet_volume': 86304},
#    {'name': 'Huerter',
#     'url': 'http://twitter.com/search?q=Huerter',
#     'promoted_content': None,
#     'query': 'Huerter',
#     'tweet_volume': None},
#    {'name': 'Splash Mountain',
#     'url': 'http://twitter.com/search?q=%22Splash+Mountain%22',
#     'promoted_content': None,
#     'query': '%22Splash+Mountain%22',
#     'tweet_volume': None},
#    {'name': 'Nesmith',
#     'url': 'http://twitter.com/search?q=Nesmith',
#     'promoted_content': None,
#     'query': 'Nesmith',
#     'tweet_volume': None},
#    {'name': 'Liberal World Order',
#     'url': 'http://twitter.com/search?q=%22Liberal+World+Order%22',
#     'promoted_content': None,
#     'query': '%22Liberal+World+Order%22',
#     'tweet_volume': 114331},
#    {'name': 'Independence Day',
#     'url': 'http://twitter.com/search?q=%22Independence+Day%22',
#     'promoted_content': None,
#     'query': '%22Independence+Day%22',
#     'tweet_volume': 38434},
#    {'name': 'Tiana',
#     'url': 'http://twitter.com/search?q=Tiana',
#     'promoted_content': None,
#     'query': 'Tiana',
#     'tweet_volume': None},
#    {'name': 'FRIDAY FACT',
#     'url': 'http://twitter.com/search?q=%22FRIDAY+FACT%22',
#     'promoted_content': None,
#     'query': '%22FRIDAY+FACT%22',
#     'tweet_volume': None},
#    {'name': 'Lou Dobbs',
#     'url': 'http://twitter.com/search?q=%22Lou+Dobbs%22',
#     'promoted_content': None,
#     'query': '%22Lou+Dobbs%22',
#     'tweet_volume': None},
#    {'name': 'Brit',
#     'url': 'http://twitter.com/search?q=Brit',
#     'promoted_content': None,
#     'query': 'Brit',
#     'tweet_volume': 13648},
#    {'name': 'Red Velvet',
#     'url': 'http://twitter.com/search?q=%22Red+Velvet%22',
#     'promoted_content': None,
#     'query': '%22Red+Velvet%22',
#     'tweet_volume': 36092},
#    {'name': 'Malik Fitts',
#     'url': 'http://twitter.com/search?q=%22Malik+Fitts%22',
#     'promoted_content': None,
#     'query': '%22Malik+Fitts%22',
#     'tweet_volume': None},
#    {'name': 'Thomas Bryant',
#     'url': 'http://twitter.com/search?q=%22Thomas+Bryant%22',
#     'promoted_content': None,
#     'query': '%22Thomas+Bryant%22',
#     'tweet_volume': None},
#    {'name': 'Presidential Medal of Freedom',
#     'url': 'http://twitter.com/search?q=%22Presidential+Medal+of+Freedom%22',
#     'promoted_content': None,
#     'query': '%22Presidential+Medal+of+Freedom%22',
#     'tweet_volume': None},
#    {'name': 'Bahamas',
#     'url': 'http://twitter.com/search?q=Bahamas',
#     'promoted_content': None,
#     'query': 'Bahamas',
#     'tweet_volume': 23991},
#    {'name': 'Pritchard',
#     'url': 'http://twitter.com/search?q=Pritchard',
#     'promoted_content': None,
#     'query': 'Pritchard',
#     'tweet_volume': None},
#    {'name': 'Fourth of July',
#     'url': 'http://twitter.com/search?q=%22Fourth+of+July%22',
#     'promoted_content': None,
#     'query': '%22Fourth+of+July%22',
#     'tweet_volume': 25028},
#    {'name': 'Sly Cooper',
#     'url': 'http://twitter.com/search?q=%22Sly+Cooper%22',
#     'promoted_content': None,
#     'query': '%22Sly+Cooper%22',
#     'tweet_volume': None},
#    {'name': 'Mike Lindell',
#     'url': 'http://twitter.com/search?q=%22Mike+Lindell%22',
#     'promoted_content': None,
#     'query': '%22Mike+Lindell%22',
#     'tweet_volume': None},
#    {'name': 'City Connect',
#     'url': 'http://twitter.com/search?q=%22City+Connect%22',
#     'promoted_content': None,
#     'query': '%22City+Connect%22',
#     'tweet_volume': None},
#    {'name': 'Gallinari',
#     'url': 'http://twitter.com/search?q=Gallinari',
#     'promoted_content': None,
#     'query': 'Gallinari',
#     'tweet_volume': 14667},
#    {'name': 'Welcome to Boston',
#     'url': 'http://twitter.com/search?q=%22Welcome+to+Boston%22',
#     'promoted_content': None,
#     'query': '%22Welcome+to+Boston%22',
#     'tweet_volume': None},
#    {'name': 'Juwan Morgan',
#     'url': 'http://twitter.com/search?q=%22Juwan+Morgan%22',
#     'promoted_content': None,
#     'query': '%22Juwan+Morgan%22',
#     'tweet_volume': None},
#    {'name': 'SMROOKIES',
#     'url': 'http://twitter.com/search?q=SMROOKIES',
#     'promoted_content': None,
#     'query': 'SMROOKIES',
#     'tweet_volume': 335701},
#    {'name': 'Ranged',
#     'url': 'http://twitter.com/search?q=Ranged',
#     'promoted_content': None,
#     'query': 'Ranged',
#     'tweet_volume': None},
#    {'name': 'Robin Lopez',
#     'url': 'http://twitter.com/search?q=%22Robin+Lopez%22',
#     'promoted_content': None,
#     'query': '%22Robin+Lopez%22',
#     'tweet_volume': None},
#    {'name': 'Otto',
#     'url': 'http://twitter.com/search?q=Otto',
#     'promoted_content': None,
#     'query': 'Otto',
#     'tweet_volume': 27121},
#    {'name': 'Song of the South',
#     'url': 'http://twitter.com/search?q=%22Song+of+the+South%22',
#     'promoted_content': None,
#     'query': '%22Song+of+the+South%22',
#     'tweet_volume': None},
#    {'name': 'Megan Rapinoe',
#     'url': 'http://twitter.com/search?q=%22Megan+Rapinoe%22',
#     'promoted_content': None,
#     'query': '%22Megan+Rapinoe%22',
#     'tweet_volume': None}],
#   'as_of': '2022-07-01T18:24:47Z',
#   'created_at': '2022-06-30T01:47:44Z',
#   'locations': [{'name': 'New York', 'woeid': 2459115}]}]

# %%
# View output as a DataFrame.
# Import Pandas.
import pandas as pd

# Create a DataFrame.
new_york_trends_pd = pd.DataFrame(new_york_trends[0]['trends'])

# View the DataFrame.
new_york_trends_pd
# Out:
#                              name  \
# 0                         #TheChi
# 1                     Bruce Brown
# 2                            Utah
# 3                           Mitch
# 4                       Canadians
# 5                           Eddie
# 6                    They're a 10
# 7                   Miles Bridges
# 8                        #TheBoys
# 9                            Zion
# 10                        #UFC276
# 11                        Brogdon
# 12                         Canada
# 13              #samsummerfridays
# 14                   Brad Stevens
# 15                         Pacers
# 16         #freecodefridaycontest
# 17                  Bobby Bonilla
# 18                        Wyoming
# 19                          Theis
# 20                    4th of July
# 21                     Liz Cheney
# 22                        Huerter
# 23                Splash Mountain
# 24                        Nesmith
# 25            Liberal World Order
# 26               Independence Day
# 27                          Tiana
# 28                    FRIDAY FACT
# 29                      Lou Dobbs
# 30                           Brit
# 31                     Red Velvet
# 32                    Malik Fitts
# 33                  Thomas Bryant
# 34  Presidential Medal of Freedom
# 35                        Bahamas
# 36                      Pritchard
# 37                 Fourth of July
# 38                     Sly Cooper
# 39                   Mike Lindell
# 40                   City Connect
# 41                      Gallinari
# 42              Welcome to Boston
# 43                   Juwan Morgan
# 44                      SMROOKIES
# 45                         Ranged
# 46                    Robin Lopez
# 47                           Otto
# 48              Song of the South
# 49                  Megan Rapinoe
#
#                                                   url promoted_content  \
# 0               http://twitter.com/search?q=%23TheChi             None
# 1       http://twitter.com/search?q=%22Bruce+Brown%22             None
# 2                    http://twitter.com/search?q=Utah             None
# 3                   http://twitter.com/search?q=Mitch             None
# 4               http://twitter.com/search?q=Canadians             None
# 5                   http://twitter.com/search?q=Eddie             None
# 6    http://twitter.com/search?q=%22They%27re+a+10%22             None
# 7     http://twitter.com/search?q=%22Miles+Bridges%22             None
# 8              http://twitter.com/search?q=%23TheBoys             None
# 9                    http://twitter.com/search?q=Zion             None
# 10              http://twitter.com/search?q=%23UFC276             None
# 11                http://twitter.com/search?q=Brogdon             None
# 12                 http://twitter.com/search?q=Canada             None
# 13    http://twitter.com/search?q=%23samsummerfridays             None
# 14     http://twitter.com/search?q=%22Brad+Stevens%22             None
# 15                 http://twitter.com/search?q=Pacers             None
# 16  http://twitter.com/search?q=%23freecodefridayc...             None
# 17    http://twitter.com/search?q=%22Bobby+Bonilla%22             None
# 18                http://twitter.com/search?q=Wyoming             None
# 19                  http://twitter.com/search?q=Theis             None
# 20      http://twitter.com/search?q=%224th+of+July%22             None
# 21       http://twitter.com/search?q=%22Liz+Cheney%22             None
# 22                http://twitter.com/search?q=Huerter             None
# 23  http://twitter.com/search?q=%22Splash+Mountain%22             None
# 24                http://twitter.com/search?q=Nesmith             None
# 25  http://twitter.com/search?q=%22Liberal+World+O...             None
# 26  http://twitter.com/search?q=%22Independence+Da...             None
# 27                  http://twitter.com/search?q=Tiana             None
# 28      http://twitter.com/search?q=%22FRIDAY+FACT%22             None
# 29        http://twitter.com/search?q=%22Lou+Dobbs%22             None
# 30                   http://twitter.com/search?q=Brit             None
# 31       http://twitter.com/search?q=%22Red+Velvet%22             None
# 32      http://twitter.com/search?q=%22Malik+Fitts%22             None
# 33    http://twitter.com/search?q=%22Thomas+Bryant%22             None
# 34  http://twitter.com/search?q=%22Presidential+Me...             None
# 35                http://twitter.com/search?q=Bahamas             None
# 36              http://twitter.com/search?q=Pritchard             None
# 37   http://twitter.com/search?q=%22Fourth+of+July%22             None
# 38       http://twitter.com/search?q=%22Sly+Cooper%22             None
# 39     http://twitter.com/search?q=%22Mike+Lindell%22             None
# 40     http://twitter.com/search?q=%22City+Connect%22             None
# 41              http://twitter.com/search?q=Gallinari             None
# 42  http://twitter.com/search?q=%22Welcome+to+Bost...             None
# 43     http://twitter.com/search?q=%22Juwan+Morgan%22             None
# 44              http://twitter.com/search?q=SMROOKIES             None
# 45                 http://twitter.com/search?q=Ranged             None
# 46      http://twitter.com/search?q=%22Robin+Lopez%22             None
# 47                   http://twitter.com/search?q=Otto             None
# 48  http://twitter.com/search?q=%22Song+of+the+Sou...             None
# 49    http://twitter.com/search?q=%22Megan+Rapinoe%22             None
#
#                                   query  tweet_volume
# 0                             %23TheChi       32650.0
# 1                     %22Bruce+Brown%22           NaN
# 2                                  Utah       36519.0
# 3                                 Mitch      173069.0
# 4                             Canadians       38954.0
# 5                                 Eddie      362105.0
# 6                  %22They%27re+a+10%22       19395.0
# 7                   %22Miles+Bridges%22       43375.0
# 8                            %23TheBoys       53405.0
# 9                                  Zion       27629.0
# 10                            %23UFC276       22495.0
# 11                              Brogdon       27873.0
# 12                               Canada      368247.0
# 13                  %23samsummerfridays           NaN
# 14                   %22Brad+Stevens%22           NaN
# 15                               Pacers       18358.0
# 16             %23freecodefridaycontest           NaN
# 17                  %22Bobby+Bonilla%22       26938.0
# 18                              Wyoming       42765.0
# 19                                Theis           NaN
# 20                    %224th+of+July%22       91055.0
# 21                     %22Liz+Cheney%22       86304.0
# 22                              Huerter           NaN
# 23                %22Splash+Mountain%22           NaN
# 24                              Nesmith           NaN
# 25            %22Liberal+World+Order%22      114331.0
# 26               %22Independence+Day%22       38434.0
# 27                                Tiana           NaN
# 28                    %22FRIDAY+FACT%22           NaN
# 29                      %22Lou+Dobbs%22           NaN
# 30                                 Brit       13648.0
# 31                     %22Red+Velvet%22       36092.0
# 32                    %22Malik+Fitts%22           NaN
# 33                  %22Thomas+Bryant%22           NaN
# 34  %22Presidential+Medal+of+Freedom%22           NaN
# 35                              Bahamas       23991.0
# 36                            Pritchard           NaN
# 37                 %22Fourth+of+July%22       25028.0
# 38                     %22Sly+Cooper%22           NaN
# 39                   %22Mike+Lindell%22           NaN
# 40                   %22City+Connect%22           NaN
# 41                            Gallinari       14667.0
# 42              %22Welcome+to+Boston%22           NaN
# 43                   %22Juwan+Morgan%22           NaN
# 44                            SMROOKIES      335701.0
# 45                               Ranged           NaN
# 46                    %22Robin+Lopez%22           NaN
# 47                                 Otto       27121.0
# 48              %22Song+of+the+South%22           NaN
# 49                  %22Megan+Rapinoe%22           NaN

# %%
# Look at common trends in London.
london_trends = twitter_api.trends.place(_id = london[0]['woeid'])

# View the output.
london_trends
# Out:
# [{'trends': [{'name': '#MoveAGeographicalPlace',
#     'url': 'http://twitter.com/search?q=%23MoveAGeographicalPlace',
#     'promoted_content': None,
#     'query': '%23MoveAGeographicalPlace',
#     'tweet_volume': None},
#    {'name': '#TheBoys',
#     'url': 'http://twitter.com/search?q=%23TheBoys',
#     'promoted_content': None,
#     'query': '%23TheBoys',
#     'tweet_volume': 53405},
#    {'name': 'Chief Whip',
#     'url': 'http://twitter.com/search?q=%22Chief+Whip%22',
#     'promoted_content': None,
#     'query': '%22Chief+Whip%22',
#     'tweet_volume': 33121},
#    {'name': '#TorySleaze',
#     'url': 'http://twitter.com/search?q=%23TorySleaze',
#     'promoted_content': None,
#     'query': '%23TorySleaze',
#     'tweet_volume': 10681},
#    {'name': 'Iain',
#     'url': 'http://twitter.com/search?q=Iain',
#     'promoted_content': None,
#     'query': 'Iain',
#     'tweet_volume': None},
#    {'name': '#NewMusicFriday',
#     'url': 'http://twitter.com/search?q=%23NewMusicFriday',
#     'promoted_content': None,
#     'query': '%23NewMusicFriday',
#     'tweet_volume': None},
#    {'name': 'Adele',
#     'url': 'http://twitter.com/search?q=Adele',
#     'promoted_content': None,
#     'query': 'Adele',
#     'tweet_volume': 22965},
#    {'name': 'hopper',
#     'url': 'http://twitter.com/search?q=hopper',
#     'promoted_content': None,
#     'query': 'hopper',
#     'tweet_volume': 43135},
#    {'name': 'Tamworth',
#     'url': 'http://twitter.com/search?q=Tamworth',
#     'promoted_content': None,
#     'query': 'Tamworth',
#     'tweet_volume': None},
#    {'name': 'Marseille',
#     'url': 'http://twitter.com/search?q=Marseille',
#     'promoted_content': None,
#     'query': 'Marseille',
#     'tweet_volume': 25443},
#    {'name': '#PlasticFreeJuly',
#     'url': 'http://twitter.com/search?q=%23PlasticFreeJuly',
#     'promoted_content': None,
#     'query': '%23PlasticFreeJuly',
#     'tweet_volume': None},
#    {'name': 'Butter',
#     'url': 'http://twitter.com/search?q=Butter',
#     'promoted_content': None,
#     'query': 'Butter',
#     'tweet_volume': 56628},
#    {'name': 'Kenwright',
#     'url': 'http://twitter.com/search?q=Kenwright',
#     'promoted_content': None,
#     'query': 'Kenwright',
#     'tweet_volume': None},
#    {'name': 'Somme',
#     'url': 'http://twitter.com/search?q=Somme',
#     'promoted_content': None,
#     'query': 'Somme',
#     'tweet_volume': 12407},
#    {'name': 'Saliba',
#     'url': 'http://twitter.com/search?q=Saliba',
#     'promoted_content': None,
#     'query': 'Saliba',
#     'tweet_volume': None},
#    {'name': 'Steve Wright',
#     'url': 'http://twitter.com/search?q=%22Steve+Wright%22',
#     'promoted_content': None,
#     'query': '%22Steve+Wright%22',
#     'tweet_volume': None},
#    {'name': 'Scott Mills',
#     'url': 'http://twitter.com/search?q=%22Scott+Mills%22',
#     'promoted_content': None,
#     'query': '%22Scott+Mills%22',
#     'tweet_volume': None},
#    {'name': 'Radio 2',
#     'url': 'http://twitter.com/search?q=%22Radio+2%22',
#     'promoted_content': None,
#     'query': '%22Radio+2%22',
#     'tweet_volume': 16649},
#    {'name': 'Pant',
#     'url': 'http://twitter.com/search?q=Pant',
#     'promoted_content': None,
#     'query': 'Pant',
#     'tweet_volume': 77669},
#    {'name': 'Rams',
#     'url': 'http://twitter.com/search?q=Rams',
#     'promoted_content': None,
#     'query': 'Rams',
#     'tweet_volume': None},
#    {'name': 'David Clowes',
#     'url': 'http://twitter.com/search?q=%22David+Clowes%22',
#     'promoted_content': None,
#     'query': '%22David+Clowes%22',
#     'tweet_volume': None},
#    {'name': 'Mo Salah',
#     'url': 'http://twitter.com/search?q=%22Mo+Salah%22',
#     'promoted_content': None,
#     'query': '%22Mo+Salah%22',
#     'tweet_volume': 30499},
#    {'name': 'Derby County',
#     'url': 'http://twitter.com/search?q=%22Derby+County%22',
#     'promoted_content': None,
#     'query': '%22Derby+County%22',
#     'tweet_volume': None},
#    {'name': 'Ken Bruce',
#     'url': 'http://twitter.com/search?q=%22Ken+Bruce%22',
#     'promoted_content': None,
#     'query': '%22Ken+Bruce%22',
#     'tweet_volume': None},
#    {'name': 'Cameron Norrie',
#     'url': 'http://twitter.com/search?q=%22Cameron+Norrie%22',
#     'promoted_content': None,
#     'query': '%22Cameron+Norrie%22',
#     'tweet_volume': None},
#    {'name': 'Lickey End',
#     'url': 'http://twitter.com/search?q=%22Lickey+End%22',
#     'promoted_content': None,
#     'query': '%22Lickey+End%22',
#     'tweet_volume': None},
#    {'name': 'Canada',
#     'url': 'http://twitter.com/search?q=Canada',
#     'promoted_content': None,
#     'query': 'Canada',
#     'tweet_volume': 368675},
#    {'name': 'Mohamed Salah',
#     'url': 'http://twitter.com/search?q=%22Mohamed+Salah%22',
#     'promoted_content': None,
#     'query': '%22Mohamed+Salah%22',
#     'tweet_volume': 21372},
#    {'name': 'Carlos Alcaraz',
#     'url': 'http://twitter.com/search?q=%22Carlos+Alcaraz%22',
#     'promoted_content': None,
#     'query': '%22Carlos+Alcaraz%22',
#     'tweet_volume': None},
#    {'name': 'Ed Dawes',
#     'url': 'http://twitter.com/search?q=%22Ed+Dawes%22',
#     'promoted_content': None,
#     'query': '%22Ed+Dawes%22',
#     'tweet_volume': None},
#    {'name': 'Wrighty',
#     'url': 'http://twitter.com/search?q=Wrighty',
#     'promoted_content': None,
#     'query': 'Wrighty',
#     'tweet_volume': None},
#    {'name': 'The Egyptian King',
#     'url': 'http://twitter.com/search?q=%22The+Egyptian+King%22',
#     'promoted_content': None,
#     'query': '%22The+Egyptian+King%22',
#     'tweet_volume': None},
#    {'name': 'Raphinha and Martinez',
#     'url': 'http://twitter.com/search?q=%22Raphinha+and+Martinez%22',
#     'promoted_content': None,
#     'query': '%22Raphinha+and+Martinez%22',
#     'tweet_volume': None},
#    {'name': 'Serious Jockin',
#     'url': 'http://twitter.com/search?q=%22Serious+Jockin%22',
#     'promoted_content': None,
#     'query': '%22Serious+Jockin%22',
#     'tweet_volume': None},
#    {'name': 'Julian Ward',
#     'url': 'http://twitter.com/search?q=%22Julian+Ward%22',
#     'promoted_content': None,
#     'query': '%22Julian+Ward%22',
#     'tweet_volume': None},
#    {'name': 'Catterall',
#     'url': 'http://twitter.com/search?q=Catterall',
#     'promoted_content': None,
#     'query': 'Catterall',
#     'tweet_volume': None},
#    {'name': 'Sara Cox',
#     'url': 'http://twitter.com/search?q=%22Sara+Cox%22',
#     'promoted_content': None,
#     'query': '%22Sara+Cox%22',
#     'tweet_volume': None},
#    {'name': 'Jadeja',
#     'url': 'http://twitter.com/search?q=Jadeja',
#     'promoted_content': None,
#     'query': 'Jadeja',
#     'tweet_volume': 13525},
#    {'name': 'Yes Mo',
#     'url': 'http://twitter.com/search?q=%22Yes+Mo%22',
#     'promoted_content': None,
#     'query': '%22Yes+Mo%22',
#     'tweet_volume': None},
#    {'name': 'Tyrell Malacia',
#     'url': 'http://twitter.com/search?q=%22Tyrell+Malacia%22',
#     'promoted_content': None,
#     'query': '%22Tyrell+Malacia%22',
#     'tweet_volume': 49536},
#    {'name': 'Jacinda',
#     'url': 'http://twitter.com/search?q=Jacinda',
#     'promoted_content': None,
#     'query': 'Jacinda',
#     'tweet_volume': None},
#    {'name': 'Gini',
#     'url': 'http://twitter.com/search?q=Gini',
#     'promoted_content': None,
#     'query': 'Gini',
#     'tweet_volume': 85228},
#    {'name': 'Taylor Harwood',
#     'url': 'http://twitter.com/search?q=%22Taylor+Harwood%22',
#     'promoted_content': None,
#     'query': '%22Taylor+Harwood%22',
#     'tweet_volume': None},
#    {'name': 'Bellis',
#     'url': 'http://twitter.com/search?q=Bellis',
#     'promoted_content': None,
#     'query': 'Bellis',
#     'tweet_volume': None},
#    {'name': 'Blundell',
#     'url': 'http://twitter.com/search?q=Blundell',
#     'promoted_content': None,
#     'query': 'Blundell',
#     'tweet_volume': None},
#    {'name': 'Heather Watson',
#     'url': 'http://twitter.com/search?q=%22Heather+Watson%22',
#     'promoted_content': None,
#     'query': '%22Heather+Watson%22',
#     'tweet_volume': None},
#    {'name': 'Tory MP',
#     'url': 'http://twitter.com/search?q=%22Tory+MP%22',
#     'promoted_content': None,
#     'query': '%22Tory+MP%22',
#     'tweet_volume': 32675},
#    {'name': 'Melee',
#     'url': 'http://twitter.com/search?q=Melee',
#     'promoted_content': None,
#     'query': 'Melee',
#     'tweet_volume': None},
#    {'name': 'Kenyon',
#     'url': 'http://twitter.com/search?q=Kenyon',
#     'promoted_content': None,
#     'query': 'Kenyon',
#     'tweet_volume': None},
#    {'name': 'Drew Busby',
#     'url': 'http://twitter.com/search?q=%22Drew+Busby%22',
#     'promoted_content': None,
#     'query': '%22Drew+Busby%22',
#     'tweet_volume': None}],
#   'as_of': '2022-07-01T18:24:50Z',
#   'created_at': '2022-06-30T10:53:19Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
# View output as a DataFrame.
# Create a DataFrame.
london_trends_pd = pd.DataFrame(london_trends[0]['trends'])

# View the DataFrame.
london_trends_pd
# Out:
#                        name  \
# 0   #MoveAGeographicalPlace
# 1                  #TheBoys
# 2                Chief Whip
# 3               #TorySleaze
# 4                      Iain
# 5           #NewMusicFriday
# 6                     Adele
# 7                    hopper
# 8                  Tamworth
# 9                 Marseille
# 10         #PlasticFreeJuly
# 11                   Butter
# 12                Kenwright
# 13                    Somme
# 14                   Saliba
# 15             Steve Wright
# 16              Scott Mills
# 17                  Radio 2
# 18                     Pant
# 19                     Rams
# 20             David Clowes
# 21                 Mo Salah
# 22             Derby County
# 23                Ken Bruce
# 24           Cameron Norrie
# 25               Lickey End
# 26                   Canada
# 27            Mohamed Salah
# 28           Carlos Alcaraz
# 29                 Ed Dawes
# 30                  Wrighty
# 31        The Egyptian King
# 32    Raphinha and Martinez
# 33           Serious Jockin
# 34              Julian Ward
# 35                Catterall
# 36                 Sara Cox
# 37                   Jadeja
# 38                   Yes Mo
# 39           Tyrell Malacia
# 40                  Jacinda
# 41                     Gini
# 42           Taylor Harwood
# 43                   Bellis
# 44                 Blundell
# 45           Heather Watson
# 46                  Tory MP
# 47                    Melee
# 48                   Kenyon
# 49               Drew Busby
#
#                                                   url promoted_content  \
# 0   http://twitter.com/search?q=%23MoveAGeographic...             None
# 1              http://twitter.com/search?q=%23TheBoys             None
# 2        http://twitter.com/search?q=%22Chief+Whip%22             None
# 3           http://twitter.com/search?q=%23TorySleaze             None
# 4                    http://twitter.com/search?q=Iain             None
# 5       http://twitter.com/search?q=%23NewMusicFriday             None
# 6                   http://twitter.com/search?q=Adele             None
# 7                  http://twitter.com/search?q=hopper             None
# 8                http://twitter.com/search?q=Tamworth             None
# 9               http://twitter.com/search?q=Marseille             None
# 10     http://twitter.com/search?q=%23PlasticFreeJuly             None
# 11                 http://twitter.com/search?q=Butter             None
# 12              http://twitter.com/search?q=Kenwright             None
# 13                  http://twitter.com/search?q=Somme             None
# 14                 http://twitter.com/search?q=Saliba             None
# 15     http://twitter.com/search?q=%22Steve+Wright%22             None
# 16      http://twitter.com/search?q=%22Scott+Mills%22             None
# 17          http://twitter.com/search?q=%22Radio+2%22             None
# 18                   http://twitter.com/search?q=Pant             None
# 19                   http://twitter.com/search?q=Rams             None
# 20     http://twitter.com/search?q=%22David+Clowes%22             None
# 21         http://twitter.com/search?q=%22Mo+Salah%22             None
# 22     http://twitter.com/search?q=%22Derby+County%22             None
# 23        http://twitter.com/search?q=%22Ken+Bruce%22             None
# 24   http://twitter.com/search?q=%22Cameron+Norrie%22             None
# 25       http://twitter.com/search?q=%22Lickey+End%22             None
# 26                 http://twitter.com/search?q=Canada             None
# 27    http://twitter.com/search?q=%22Mohamed+Salah%22             None
# 28   http://twitter.com/search?q=%22Carlos+Alcaraz%22             None
# 29         http://twitter.com/search?q=%22Ed+Dawes%22             None
# 30                http://twitter.com/search?q=Wrighty             None
# 31  http://twitter.com/search?q=%22The+Egyptian+Ki...             None
# 32  http://twitter.com/search?q=%22Raphinha+and+Ma...             None
# 33   http://twitter.com/search?q=%22Serious+Jockin%22             None
# 34      http://twitter.com/search?q=%22Julian+Ward%22             None
# 35              http://twitter.com/search?q=Catterall             None
# 36         http://twitter.com/search?q=%22Sara+Cox%22             None
# 37                 http://twitter.com/search?q=Jadeja             None
# 38           http://twitter.com/search?q=%22Yes+Mo%22             None
# 39   http://twitter.com/search?q=%22Tyrell+Malacia%22             None
# 40                http://twitter.com/search?q=Jacinda             None
# 41                   http://twitter.com/search?q=Gini             None
# 42   http://twitter.com/search?q=%22Taylor+Harwood%22             None
# 43                 http://twitter.com/search?q=Bellis             None
# 44               http://twitter.com/search?q=Blundell             None
# 45   http://twitter.com/search?q=%22Heather+Watson%22             None
# 46          http://twitter.com/search?q=%22Tory+MP%22             None
# 47                  http://twitter.com/search?q=Melee             None
# 48                 http://twitter.com/search?q=Kenyon             None
# 49       http://twitter.com/search?q=%22Drew+Busby%22             None
#
#                           query  tweet_volume
# 0     %23MoveAGeographicalPlace           NaN
# 1                    %23TheBoys       53405.0
# 2              %22Chief+Whip%22       33121.0
# 3                 %23TorySleaze       10681.0
# 4                          Iain           NaN
# 5             %23NewMusicFriday           NaN
# 6                         Adele       22965.0
# 7                        hopper       43135.0
# 8                      Tamworth           NaN
# 9                     Marseille       25443.0
# 10           %23PlasticFreeJuly           NaN
# 11                       Butter       56628.0
# 12                    Kenwright           NaN
# 13                        Somme       12407.0
# 14                       Saliba           NaN
# 15           %22Steve+Wright%22           NaN
# 16            %22Scott+Mills%22           NaN
# 17                %22Radio+2%22       16649.0
# 18                         Pant       77669.0
# 19                         Rams           NaN
# 20           %22David+Clowes%22           NaN
# 21               %22Mo+Salah%22       30499.0
# 22           %22Derby+County%22           NaN
# 23              %22Ken+Bruce%22           NaN
# 24         %22Cameron+Norrie%22           NaN
# 25             %22Lickey+End%22           NaN
# 26                       Canada      368675.0
# 27          %22Mohamed+Salah%22       21372.0
# 28         %22Carlos+Alcaraz%22           NaN
# 29               %22Ed+Dawes%22           NaN
# 30                      Wrighty           NaN
# 31      %22The+Egyptian+King%22           NaN
# 32  %22Raphinha+and+Martinez%22           NaN
# 33         %22Serious+Jockin%22           NaN
# 34            %22Julian+Ward%22           NaN
# 35                    Catterall           NaN
# 36               %22Sara+Cox%22           NaN
# 37                       Jadeja       13525.0
# 38                 %22Yes+Mo%22           NaN
# 39         %22Tyrell+Malacia%22       49536.0
# 40                      Jacinda           NaN
# 41                         Gini       85228.0
# 42         %22Taylor+Harwood%22           NaN
# 43                       Bellis           NaN
# 44                     Blundell           NaN
# 45         %22Heather+Watson%22           NaN
# 46                %22Tory+MP%22       32675.0
# 47                        Melee           NaN
# 48                       Kenyon           NaN
# 49             %22Drew+Busby%22           NaN

# %%
# Limit the output to more than 50,000 tweets for New York.
new_york_trends_over50k_pd = new_york_trends_pd[new_york_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(new_york_trends_over50k_pd.shape)
new_york_trends_over50k_pd
# Out:
# (8, 5)
#                    name                                                url  \
# 12               Canada                 http://twitter.com/search?q=Canada
# 5                 Eddie                  http://twitter.com/search?q=Eddie
# 44            SMROOKIES              http://twitter.com/search?q=SMROOKIES
# 3                 Mitch                  http://twitter.com/search?q=Mitch
# 25  Liberal World Order  http://twitter.com/search?q=%22Liberal+World+O...
# 20          4th of July      http://twitter.com/search?q=%224th+of+July%22
# 21           Liz Cheney       http://twitter.com/search?q=%22Liz+Cheney%22
# 8              #TheBoys             http://twitter.com/search?q=%23TheBoys
#
#    promoted_content                      query  tweet_volume
# 12             None                     Canada      368247.0
# 5              None                      Eddie      362105.0
# 44             None                  SMROOKIES      335701.0
# 3              None                      Mitch      173069.0
# 25             None  %22Liberal+World+Order%22      114331.0
# 20             None          %224th+of+July%22       91055.0
# 21             None           %22Liz+Cheney%22       86304.0
# 8              None                 %23TheBoys       53405.0

# %%
# Limit the output to more than 50,000 tweets for London.
london_trends_over50k_pd = london_trends_pd[london_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(london_trends_over50k_pd.shape)
london_trends_over50k_pd
# Out:
# (5, 5)
#         name                                     url promoted_content  \
# 26    Canada      http://twitter.com/search?q=Canada             None
# 41      Gini        http://twitter.com/search?q=Gini             None
# 18      Pant        http://twitter.com/search?q=Pant             None
# 11    Butter      http://twitter.com/search?q=Butter             None
# 1   #TheBoys  http://twitter.com/search?q=%23TheBoys             None
#
#          query  tweet_volume
# 26      Canada      368675.0
# 41        Gini       85228.0
# 18        Pant       77669.0
# 11      Butter       56628.0
# 1   %23TheBoys       53405.0

# %%
# Save output as CSV file for New York.
new_york_trends_over50k_pd.to_csv('new_york_over50k.csv', index=False)

# %%
# Save output as CSV file for London.
london_trends_over50k_pd.to_csv('london_over50k.csv', index=False)

# %%
# Find the common trends between New York and London.
ny_trends_list = [trend['name'] for trend in new_york_trends[0]['trends']]

# View the output.
print(ny_trends_list)
# Out:
# ['#TheChi', 'Bruce Brown', 'Utah', 'Mitch', 'Canadians', 'Eddie', "They're a 10", 'Miles Bridges', '#TheBoys', 'Zion', '#UFC276', 'Brogdon', 'Canada', '#samsummerfridays', 'Brad Stevens', 'Pacers', '#freecodefridaycontest', 'Bobby Bonilla', 'Wyoming', 'Theis', '4th of July', 'Liz Cheney', 'Huerter', 'Splash Mountain', 'Nesmith', 'Liberal World Order', 'Independence Day', 'Tiana', 'FRIDAY FACT', 'Lou Dobbs', 'Brit', 'Red Velvet', 'Malik Fitts', 'Thomas Bryant', 'Presidential Medal of Freedom', 'Bahamas', 'Pritchard', 'Fourth of July', 'Sly Cooper', 'Mike Lindell', 'City Connect', 'Gallinari', 'Welcome to Boston', 'Juwan Morgan', 'SMROOKIES', 'Ranged', 'Robin Lopez', 'Otto', 'Song of the South', 'Megan Rapinoe']

# %%
# Find common topic(s).
london_trends_list =[trend['name'] for trend in london_trends[0]['trends']]

# View the output.
print(london_trends_list)
# Out:
# ['#MoveAGeographicalPlace', '#TheBoys', 'Chief Whip', '#TorySleaze', 'Iain', '#NewMusicFriday', 'Adele', 'hopper', 'Tamworth', 'Marseille', '#PlasticFreeJuly', 'Butter', 'Kenwright', 'Somme', 'Saliba', 'Steve Wright', 'Scott Mills', 'Radio 2', 'Pant', 'Rams', 'David Clowes', 'Mo Salah', 'Derby County', 'Ken Bruce', 'Cameron Norrie', 'Lickey End', 'Canada', 'Mohamed Salah', 'Carlos Alcaraz', 'Ed Dawes', 'Wrighty', 'The Egyptian King', 'Raphinha and Martinez', 'Serious Jockin', 'Julian Ward', 'Catterall', 'Sara Cox', 'Jadeja', 'Yes Mo', 'Tyrell Malacia', 'Jacinda', 'Gini', 'Taylor Harwood', 'Bellis', 'Blundell', 'Heather Watson', 'Tory MP', 'Melee', 'Kenyon', 'Drew Busby']

# %%
# Create a variable.
new_york = [_ for _ in trends_worldwide if _['name'] == US]

# View the output.
new_york[0]['woeid']
# Out:
# 2459115

# %%
# Import JSON.
import json

# Search for Cape Town.
ny_trends = twitter_api.trends.place(_id=2459115)

# View JSON output.
print (json.dumps(ny_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "#TheChi",
#                 "url": "http://twitter.com/search?q=%23TheChi",
#                 "promoted_content": null,
#                 "query": "%23TheChi",
#                 "tweet_volume": 32650
#             },
#             {
#                 "name": "Bruce Brown",
#                 "url": "http://twitter.com/search?q=%22Bruce+Brown%22",
#                 "promoted_content": null,
#                 "query": "%22Bruce+Brown%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Utah",
#                 "url": "http://twitter.com/search?q=Utah",
#                 "promoted_content": null,
#                 "query": "Utah",
#                 "tweet_volume": 36498
#             },
#             {
#                 "name": "Mitch",
#                 "url": "http://twitter.com/search?q=Mitch",
#                 "promoted_content": null,
#                 "query": "Mitch",
#                 "tweet_volume": 173170
#             },
#             {
#                 "name": "Canadians",
#                 "url": "http://twitter.com/search?q=Canadians",
#                 "promoted_content": null,
#                 "query": "Canadians",
#                 "tweet_volume": 38954
#             },
#             {
#                 "name": "Eddie",
#                 "url": "http://twitter.com/search?q=Eddie",
#                 "promoted_content": null,
#                 "query": "Eddie",
#                 "tweet_volume": 362105
#             },
#             {
#                 "name": "They're a 10",
#                 "url": "http://twitter.com/search?q=%22They%27re+a+10%22",
#                 "promoted_content": null,
#                 "query": "%22They%27re+a+10%22",
#                 "tweet_volume": 19395
#             },
#             {
#                 "name": "Miles Bridges",
#                 "url": "http://twitter.com/search?q=%22Miles+Bridges%22",
#                 "promoted_content": null,
#                 "query": "%22Miles+Bridges%22",
#                 "tweet_volume": 43375
#             },
#             {
#                 "name": "#TheBoys",
#                 "url": "http://twitter.com/search?q=%23TheBoys",
#                 "promoted_content": null,
#                 "query": "%23TheBoys",
#                 "tweet_volume": 53362
#             },
#             {
#                 "name": "Zion",
#                 "url": "http://twitter.com/search?q=Zion",
#                 "promoted_content": null,
#                 "query": "Zion",
#                 "tweet_volume": 27640
#             },
#             {
#                 "name": "#UFC276",
#                 "url": "http://twitter.com/search?q=%23UFC276",
#                 "promoted_content": null,
#                 "query": "%23UFC276",
#                 "tweet_volume": 22506
#             },
#             {
#                 "name": "Brogdon",
#                 "url": "http://twitter.com/search?q=Brogdon",
#                 "promoted_content": null,
#                 "query": "Brogdon",
#                 "tweet_volume": 27873
#             },
#             {
#                 "name": "Canada",
#                 "url": "http://twitter.com/search?q=Canada",
#                 "promoted_content": null,
#                 "query": "Canada",
#                 "tweet_volume": 368675
#             },
#             {
#                 "name": "#samsummerfridays",
#                 "url": "http://twitter.com/search?q=%23samsummerfridays",
#                 "promoted_content": null,
#                 "query": "%23samsummerfridays",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Brad Stevens",
#                 "url": "http://twitter.com/search?q=%22Brad+Stevens%22",
#                 "promoted_content": null,
#                 "query": "%22Brad+Stevens%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Pacers",
#                 "url": "http://twitter.com/search?q=Pacers",
#                 "promoted_content": null,
#                 "query": "Pacers",
#                 "tweet_volume": 18358
#             },
#             {
#                 "name": "#freecodefridaycontest",
#                 "url": "http://twitter.com/search?q=%23freecodefridaycontest",
#                 "promoted_content": null,
#                 "query": "%23freecodefridaycontest",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Bobby Bonilla",
#                 "url": "http://twitter.com/search?q=%22Bobby+Bonilla%22",
#                 "promoted_content": null,
#                 "query": "%22Bobby+Bonilla%22",
#                 "tweet_volume": 26938
#             },
#             {
#                 "name": "Wyoming",
#                 "url": "http://twitter.com/search?q=Wyoming",
#                 "promoted_content": null,
#                 "query": "Wyoming",
#                 "tweet_volume": 42713
#             },
#             {
#                 "name": "Theis",
#                 "url": "http://twitter.com/search?q=Theis",
#                 "promoted_content": null,
#                 "query": "Theis",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "4th of July",
#                 "url": "http://twitter.com/search?q=%224th+of+July%22",
#                 "promoted_content": null,
#                 "query": "%224th+of+July%22",
#                 "tweet_volume": 91055
#             },
#             {
#                 "name": "Liz Cheney",
#                 "url": "http://twitter.com/search?q=%22Liz+Cheney%22",
#                 "promoted_content": null,
#                 "query": "%22Liz+Cheney%22",
#                 "tweet_volume": 86304
#             },
#             {
#                 "name": "Huerter",
#                 "url": "http://twitter.com/search?q=Huerter",
#                 "promoted_content": null,
#                 "query": "Huerter",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Splash Mountain",
#                 "url": "http://twitter.com/search?q=%22Splash+Mountain%22",
#                 "promoted_content": null,
#                 "query": "%22Splash+Mountain%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Nesmith",
#                 "url": "http://twitter.com/search?q=Nesmith",
#                 "promoted_content": null,
#                 "query": "Nesmith",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Liberal World Order",
#                 "url": "http://twitter.com/search?q=%22Liberal+World+Order%22",
#                 "promoted_content": null,
#                 "query": "%22Liberal+World+Order%22",
#                 "tweet_volume": 114331
#             },
#             {
#                 "name": "Independence Day",
#                 "url": "http://twitter.com/search?q=%22Independence+Day%22",
#                 "promoted_content": null,
#                 "query": "%22Independence+Day%22",
#                 "tweet_volume": 38473
#             },
#             {
#                 "name": "Tiana",
#                 "url": "http://twitter.com/search?q=Tiana",
#                 "promoted_content": null,
#                 "query": "Tiana",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "FRIDAY FACT",
#                 "url": "http://twitter.com/search?q=%22FRIDAY+FACT%22",
#                 "promoted_content": null,
#                 "query": "%22FRIDAY+FACT%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Lou Dobbs",
#                 "url": "http://twitter.com/search?q=%22Lou+Dobbs%22",
#                 "promoted_content": null,
#                 "query": "%22Lou+Dobbs%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Brit",
#                 "url": "http://twitter.com/search?q=Brit",
#                 "promoted_content": null,
#                 "query": "Brit",
#                 "tweet_volume": 13697
#             },
#             {
#                 "name": "Red Velvet",
#                 "url": "http://twitter.com/search?q=%22Red+Velvet%22",
#                 "promoted_content": null,
#                 "query": "%22Red+Velvet%22",
#                 "tweet_volume": 36092
#             },
#             {
#                 "name": "Malik Fitts",
#                 "url": "http://twitter.com/search?q=%22Malik+Fitts%22",
#                 "promoted_content": null,
#                 "query": "%22Malik+Fitts%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Presidential Medal of Freedom",
#                 "url": "http://twitter.com/search?q=%22Presidential+Medal+of+Freedom%22",
#                 "promoted_content": null,
#                 "query": "%22Presidential+Medal+of+Freedom%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Thomas Bryant",
#                 "url": "http://twitter.com/search?q=%22Thomas+Bryant%22",
#                 "promoted_content": null,
#                 "query": "%22Thomas+Bryant%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Bahamas",
#                 "url": "http://twitter.com/search?q=Bahamas",
#                 "promoted_content": null,
#                 "query": "Bahamas",
#                 "tweet_volume": 23991
#             },
#             {
#                 "name": "Pritchard",
#                 "url": "http://twitter.com/search?q=Pritchard",
#                 "promoted_content": null,
#                 "query": "Pritchard",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Fourth of July",
#                 "url": "http://twitter.com/search?q=%22Fourth+of+July%22",
#                 "promoted_content": null,
#                 "query": "%22Fourth+of+July%22",
#                 "tweet_volume": 25028
#             },
#             {
#                 "name": "Sly Cooper",
#                 "url": "http://twitter.com/search?q=%22Sly+Cooper%22",
#                 "promoted_content": null,
#                 "query": "%22Sly+Cooper%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Mike Lindell",
#                 "url": "http://twitter.com/search?q=%22Mike+Lindell%22",
#                 "promoted_content": null,
#                 "query": "%22Mike+Lindell%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "City Connect",
#                 "url": "http://twitter.com/search?q=%22City+Connect%22",
#                 "promoted_content": null,
#                 "query": "%22City+Connect%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Gallinari",
#                 "url": "http://twitter.com/search?q=Gallinari",
#                 "promoted_content": null,
#                 "query": "Gallinari",
#                 "tweet_volume": 14667
#             },
#             {
#                 "name": "Welcome to Boston",
#                 "url": "http://twitter.com/search?q=%22Welcome+to+Boston%22",
#                 "promoted_content": null,
#                 "query": "%22Welcome+to+Boston%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Juwan Morgan",
#                 "url": "http://twitter.com/search?q=%22Juwan+Morgan%22",
#                 "promoted_content": null,
#                 "query": "%22Juwan+Morgan%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "SMROOKIES",
#                 "url": "http://twitter.com/search?q=SMROOKIES",
#                 "promoted_content": null,
#                 "query": "SMROOKIES",
#                 "tweet_volume": 335701
#             },
#             {
#                 "name": "Ranged",
#                 "url": "http://twitter.com/search?q=Ranged",
#                 "promoted_content": null,
#                 "query": "Ranged",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Robin Lopez",
#                 "url": "http://twitter.com/search?q=%22Robin+Lopez%22",
#                 "promoted_content": null,
#                 "query": "%22Robin+Lopez%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Otto",
#                 "url": "http://twitter.com/search?q=Otto",
#                 "promoted_content": null,
#                 "query": "Otto",
#                 "tweet_volume": 27140
#             },
#             {
#                 "name": "Song of the South",
#                 "url": "http://twitter.com/search?q=%22Song+of+the+South%22",
#                 "promoted_content": null,
#                 "query": "%22Song+of+the+South%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Megan Rapinoe",
#                 "url": "http://twitter.com/search?q=%22Megan+Rapinoe%22",
#                 "promoted_content": null,
#                 "query": "%22Megan+Rapinoe%22",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-07-01T18:24:50Z",
#         "created_at": "2022-06-30T01:47:44Z",
#         "locations": [
#             {
#                 "name": "New York",
#                 "woeid": 2459115
#             }
#         ]
#     }
# ]

# %%
# Create a variable.
london = [_ for _ in trends_worldwide if _['name'] == UK]

# View the output.
london[0]['woeid']
# Out:
# 44418

# %%
# Search for Cape Town.
london_trends = twitter_api.trends.place(_id=44418)

# View JSON output.
print (json.dumps(london_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "#TheBoys",
#                 "url": "http://twitter.com/search?q=%23TheBoys",
#                 "promoted_content": null,
#                 "query": "%23TheBoys",
#                 "tweet_volume": 53362
#             },
#             {
#                 "name": "#SkyF1",
#                 "url": "http://twitter.com/search?q=%23SkyF1",
#                 "promoted_content": null,
#                 "query": "%23SkyF1",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Chief Whip",
#                 "url": "http://twitter.com/search?q=%22Chief+Whip%22",
#                 "promoted_content": null,
#                 "query": "%22Chief+Whip%22",
#                 "tweet_volume": 33121
#             },
#             {
#                 "name": "#TorySleaze",
#                 "url": "http://twitter.com/search?q=%23TorySleaze",
#                 "promoted_content": null,
#                 "query": "%23TorySleaze",
#                 "tweet_volume": 10690
#             },
#             {
#                 "name": "Iain",
#                 "url": "http://twitter.com/search?q=Iain",
#                 "promoted_content": null,
#                 "query": "Iain",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#NewMusicFriday",
#                 "url": "http://twitter.com/search?q=%23NewMusicFriday",
#                 "promoted_content": null,
#                 "query": "%23NewMusicFriday",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Adele",
#                 "url": "http://twitter.com/search?q=Adele",
#                 "promoted_content": null,
#                 "query": "Adele",
#                 "tweet_volume": 22965
#             },
#             {
#                 "name": "hopper",
#                 "url": "http://twitter.com/search?q=hopper",
#                 "promoted_content": null,
#                 "query": "hopper",
#                 "tweet_volume": 43135
#             },
#             {
#                 "name": "Tamworth",
#                 "url": "http://twitter.com/search?q=Tamworth",
#                 "promoted_content": null,
#                 "query": "Tamworth",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Marseille",
#                 "url": "http://twitter.com/search?q=Marseille",
#                 "promoted_content": null,
#                 "query": "Marseille",
#                 "tweet_volume": 25443
#             },
#             {
#                 "name": "#PlasticFreeJuly",
#                 "url": "http://twitter.com/search?q=%23PlasticFreeJuly",
#                 "promoted_content": null,
#                 "query": "%23PlasticFreeJuly",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Butter",
#                 "url": "http://twitter.com/search?q=Butter",
#                 "promoted_content": null,
#                 "query": "Butter",
#                 "tweet_volume": 56603
#             },
#             {
#                 "name": "Kenwright",
#                 "url": "http://twitter.com/search?q=Kenwright",
#                 "promoted_content": null,
#                 "query": "Kenwright",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Somme",
#                 "url": "http://twitter.com/search?q=Somme",
#                 "promoted_content": null,
#                 "query": "Somme",
#                 "tweet_volume": 12397
#             },
#             {
#                 "name": "Saliba",
#                 "url": "http://twitter.com/search?q=Saliba",
#                 "promoted_content": null,
#                 "query": "Saliba",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Steve Wright",
#                 "url": "http://twitter.com/search?q=%22Steve+Wright%22",
#                 "promoted_content": null,
#                 "query": "%22Steve+Wright%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Scott Mills",
#                 "url": "http://twitter.com/search?q=%22Scott+Mills%22",
#                 "promoted_content": null,
#                 "query": "%22Scott+Mills%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Radio 2",
#                 "url": "http://twitter.com/search?q=%22Radio+2%22",
#                 "promoted_content": null,
#                 "query": "%22Radio+2%22",
#                 "tweet_volume": 16649
#             },
#             {
#                 "name": "Pant",
#                 "url": "http://twitter.com/search?q=Pant",
#                 "promoted_content": null,
#                 "query": "Pant",
#                 "tweet_volume": 77669
#             },
#             {
#                 "name": "Rams",
#                 "url": "http://twitter.com/search?q=Rams",
#                 "promoted_content": null,
#                 "query": "Rams",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "David Clowes",
#                 "url": "http://twitter.com/search?q=%22David+Clowes%22",
#                 "promoted_content": null,
#                 "query": "%22David+Clowes%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Mo Salah",
#                 "url": "http://twitter.com/search?q=%22Mo+Salah%22",
#                 "promoted_content": null,
#                 "query": "%22Mo+Salah%22",
#                 "tweet_volume": 30499
#             },
#             {
#                 "name": "Derby County",
#                 "url": "http://twitter.com/search?q=%22Derby+County%22",
#                 "promoted_content": null,
#                 "query": "%22Derby+County%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ken Bruce",
#                 "url": "http://twitter.com/search?q=%22Ken+Bruce%22",
#                 "promoted_content": null,
#                 "query": "%22Ken+Bruce%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Lickey End",
#                 "url": "http://twitter.com/search?q=%22Lickey+End%22",
#                 "promoted_content": null,
#                 "query": "%22Lickey+End%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Cameron Norrie",
#                 "url": "http://twitter.com/search?q=%22Cameron+Norrie%22",
#                 "promoted_content": null,
#                 "query": "%22Cameron+Norrie%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Canada",
#                 "url": "http://twitter.com/search?q=Canada",
#                 "promoted_content": null,
#                 "query": "Canada",
#                 "tweet_volume": 368247
#             },
#             {
#                 "name": "Ed Dawes",
#                 "url": "http://twitter.com/search?q=%22Ed+Dawes%22",
#                 "promoted_content": null,
#                 "query": "%22Ed+Dawes%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Mohamed Salah",
#                 "url": "http://twitter.com/search?q=%22Mohamed+Salah%22",
#                 "promoted_content": null,
#                 "query": "%22Mohamed+Salah%22",
#                 "tweet_volume": 21372
#             },
#             {
#                 "name": "Carlos Alcaraz",
#                 "url": "http://twitter.com/search?q=%22Carlos+Alcaraz%22",
#                 "promoted_content": null,
#                 "query": "%22Carlos+Alcaraz%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "The Egyptian King",
#                 "url": "http://twitter.com/search?q=%22The+Egyptian+King%22",
#                 "promoted_content": null,
#                 "query": "%22The+Egyptian+King%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Wrighty",
#                 "url": "http://twitter.com/search?q=Wrighty",
#                 "promoted_content": null,
#                 "query": "Wrighty",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Raphinha and Martinez",
#                 "url": "http://twitter.com/search?q=%22Raphinha+and+Martinez%22",
#                 "promoted_content": null,
#                 "query": "%22Raphinha+and+Martinez%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Serious Jockin",
#                 "url": "http://twitter.com/search?q=%22Serious+Jockin%22",
#                 "promoted_content": null,
#                 "query": "%22Serious+Jockin%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Julian Ward",
#                 "url": "http://twitter.com/search?q=%22Julian+Ward%22",
#                 "promoted_content": null,
#                 "query": "%22Julian+Ward%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Catterall",
#                 "url": "http://twitter.com/search?q=Catterall",
#                 "promoted_content": null,
#                 "query": "Catterall",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Sara Cox",
#                 "url": "http://twitter.com/search?q=%22Sara+Cox%22",
#                 "promoted_content": null,
#                 "query": "%22Sara+Cox%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Jadeja",
#                 "url": "http://twitter.com/search?q=Jadeja",
#                 "promoted_content": null,
#                 "query": "Jadeja",
#                 "tweet_volume": 13525
#             },
#             {
#                 "name": "Yes Mo",
#                 "url": "http://twitter.com/search?q=%22Yes+Mo%22",
#                 "promoted_content": null,
#                 "query": "%22Yes+Mo%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Tyrell Malacia",
#                 "url": "http://twitter.com/search?q=%22Tyrell+Malacia%22",
#                 "promoted_content": null,
#                 "query": "%22Tyrell+Malacia%22",
#                 "tweet_volume": 49763
#             },
#             {
#                 "name": "Jacinda",
#                 "url": "http://twitter.com/search?q=Jacinda",
#                 "promoted_content": null,
#                 "query": "Jacinda",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Gini",
#                 "url": "http://twitter.com/search?q=Gini",
#                 "promoted_content": null,
#                 "query": "Gini",
#                 "tweet_volume": 85228
#             },
#             {
#                 "name": "Taylor Harwood",
#                 "url": "http://twitter.com/search?q=%22Taylor+Harwood%22",
#                 "promoted_content": null,
#                 "query": "%22Taylor+Harwood%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Bellis",
#                 "url": "http://twitter.com/search?q=Bellis",
#                 "promoted_content": null,
#                 "query": "Bellis",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Blundell",
#                 "url": "http://twitter.com/search?q=Blundell",
#                 "promoted_content": null,
#                 "query": "Blundell",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Heather Watson",
#                 "url": "http://twitter.com/search?q=%22Heather+Watson%22",
#                 "promoted_content": null,
#                 "query": "%22Heather+Watson%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Tory MP",
#                 "url": "http://twitter.com/search?q=%22Tory+MP%22",
#                 "promoted_content": null,
#                 "query": "%22Tory+MP%22",
#                 "tweet_volume": 32675
#             },
#             {
#                 "name": "Melee",
#                 "url": "http://twitter.com/search?q=Melee",
#                 "promoted_content": null,
#                 "query": "Melee",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Kenyon",
#                 "url": "http://twitter.com/search?q=Kenyon",
#                 "promoted_content": null,
#                 "query": "Kenyon",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Drew Busby",
#                 "url": "http://twitter.com/search?q=%22Drew+Busby%22",
#                 "promoted_content": null,
#                 "query": "%22Drew+Busby%22",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-07-01T18:24:51Z",
#         "created_at": "2022-06-30T10:53:19Z",
#         "locations": [
#             {
#                 "name": "London",
#                 "woeid": 44418
#             }
#         ]
#     }
# ]

# %%
# Find common trends between cities.
ny_trends_set = set(ny_trends_list)
london_trends_set = set(london_trends_list)

# Set the variable.
common_trends = ny_trends_set.intersection(london_trends_set)

# View the output.
print(common_trends)
# Out:
# {'Canada', '#TheBoys'}

# %%
# Search for Bitcoin.
q = '#Bitcoin'

# Set count to 100.
Count = 100

# %%
# Read some tweets.
search_results = twitter_api.search.tweets(q=q, count=100)

statuses = search_results['statuses']

# %%
for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

print(json.dumps(statuses, indent=4))
# Out:
# Length of statuses 88
# Length of statuses 188
# Length of statuses 188
# [
#     {
#         "created_at": "Fri Jul 01 18:24:50 +0000 2022",
#         "id": 1542937287524245510,
#         "id_str": "1542937287524245510",
#         "text": "Bad sheet #Bitcoin",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Bitcoin",
#                     "indices": [
#                         10,
#                         18
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 122322732,
#             "id_str": "122322732",
#             "name": "FINE ART LESSONS / SANAT DERSLER\u0130",
#             "screen_name": "krafiker",
#             "location": "Europa",
#             "description": "Hobi resim, karakalem, hayali resim, bilsem s\u0131nav\u0131na hazrl\u0131k, \u00f6zel yetenek s\u0131nav\u0131na haz\u0131rl\u0131k, suluboya, ya\u011fl\u0131boya, toz pastel, illustrasyon, graffiti, spray art",
#             "url": "https://t.co/Nhdj5mNgJs",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/Nhdj5mNgJs",
#                             "expanded_url": "https://www.youtube.com/channel/UC94okhwcCzziKTXA5rK6cOA",
#                             "display_url": "youtube.com/channel/UC94ok\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 812,
#             "friends_count": 869,
#             "listed_count": 6,
#             "created_at": "Fri Mar 12 09:35:42 +0000 2010",
#             "favourites_count": 1702,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 2316,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme6/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme6/bg.gif",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1328758148686110722/HgqaNGss_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1328758148686110722/HgqaNGss_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/122322732/1605635609",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "B2E09B",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Fri Jul 01 18:24:50 +0000 2022",
#         "id": 1542937286500835329,
#         "id_str": "1542937286500835329",
#         "text": "RT @CryptoBusy: \ud83d\udea8 $1,000 #GIVEAWAY \ud83d\udea8\n\nTO ENTER:\n\n\u2705 FOLLOW @CryptoBusy\n\u2764\ufe0f LIKE this Tweet\n\nTo help buy up the #Bitcoin dip we are giving awa\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "GIVEAWAY",
#                     "indices": [
#                         25,
#                         34
#                     ]
#                 },
#                 {
#                     "text": "Bitcoin",
#                     "indices": [
#                         109,
#                         117
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "CryptoBusy",
#                     "name": "CryptoBusy",
#                     "id": 970698661364715520,
#                     "id_str": "970698661364715520",
#                     "indices": [
#                         3,
#                         14
#                     ]
#                 },
#                 {
#                     "screen_name": "CryptoBusy",
#                     "name": "CryptoBusy",
#                     "id": 970698661364715520,
#                     "id_str": "970698661364715520",
#                     "indices": [
#                         58,
#                         69
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1518583472708853761,
#             "id_str": "1518583472708853761",
#             "name": "ScRaMeUu33",
#             "screen_name": "ScRaMeUuETH",
#             "location": "France",
#             "description": "NFT Addict / #STEPN Runner",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 125,
#             "friends_count": 1259,
#             "listed_count": 0,
#             "created_at": "Mon Apr 25 13:31:36 +0000 2022",
#             "favourites_count": 4359,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 3039,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1521964172245979137/KEHBWRsp_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1521964172245979137/KEHBWRsp_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1518583472708853761/1651856958",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Fri Jul 01 17:56:52 +0000 2022",
#             "id": 1542930251164049409,
#             "id_str": "1542930251164049409",
#             "text": "\ud83d\udea8 $1,000 #GIVEAWAY \ud83d\udea8\n\nTO ENTER:\n\n\u2705 FOLLOW @CryptoBusy\n\u2764\ufe0f LIKE this Tweet\n\nTo help buy up the #Bitcoin dip we are gi\u2026 https://t.co/uCa5kRVEnh",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "GIVEAWAY",
#                         "indices": [
#                             9,
#                             18
#                         ]
#                     },
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             93,
#                             101
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "CryptoBusy",
#                         "name": "CryptoBusy",
#                         "id": 970698661364715520,
#                         "id_str": "970698661364715520",
#                         "indices": [
#                             42,
#                             53
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/uCa5kRVEnh",
#                         "expanded_url": "https://twitter.com/i/web/status/1542930251164049409",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 970698661364715520,
#                 "id_str": "970698661364715520",
#                 "name": "CryptoBusy",
#                 "screen_name": "CryptoBusy",
#                 "location": "England, United Kingdom",
#                 "description": "Follow for Daily #Bitcoin & #Crypto Updates | \ud83c\udfa5 YouTube: 210k | Josh & Tom | Crypto Investors & Traders | Tweets are NOT financial advice",
#                 "url": "https://t.co/AUvTkRkhWE",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/AUvTkRkhWE",
#                                 "expanded_url": "https://www.youtube.com/channel/UCBLftV9ZsgTxoMZWPfIUKGw",
#                                 "display_url": "youtube.com/channel/UCBLft\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 93459,
#                 "friends_count": 96,
#                 "listed_count": 183,
#                 "created_at": "Mon Mar 05 16:32:50 +0000 2018",
#                 "favourites_count": 2564,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 3517,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1518611354319474693/vrmXFUUv_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1518611354319474693/vrmXFUUv_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/970698661364715520/1656432276",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 434,
#             "favorite_count": 815,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 434,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Fri Jul 01 18:24:47 +0000 2022",
#         "id": 1542937277046738944,
#         "id_str": "1542937277046738944",
#         "text": "RT @rovercrc: #Bitcoin dumped over 75%. \n\nI think that's enough.",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Bitcoin",
#                     "indices": [
#                         14,
#                         22
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "rovercrc",
#                     "name": "Crypto Rover",
#                     "id": 1353384573435056128,
#                     "id_str": "1353384573435056128",
#                     "indices": [
#                         3,
#                         12
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1473356033708142592,
#             "id_str": "1473356033708142592",
#             "name": "chenxiaoli",
#             "screen_name": "NiceBeli1985",
#             "location": "New York, USA",
#             "description": "love life love yourself",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 162,
#             "friends_count": 551,
#             "listed_count": 1,
#             "created_at": "Tue Dec 21 18:13:56 +0000 2021",
#             "favourites_count": 805,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 867,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1537501755780411392/dKtatz3U_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1537501755780411392/dKtatz3U_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1473356033708142592/1655206998",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Fri Jul 01 18:11:00 +0000 2022",
#             "id": 1542933805513617408,
#             "id_str": "1542933805513617408",
#             "text": "#Bitcoin dumped over 75%. \n\nI think that's enough.",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             0,
#                             8
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1353384573435056128,
#                 "id_str": "1353384573435056128",
#                 "name": "Crypto Rover",
#                 "screen_name": "rovercrc",
#                 "location": "Bitcoin \ud83e\udd29\ud83c\udf19",
#                 "description": "\ud83c\udfa5 YouTube (80k): Crypto Rover with daily technical analysis uploads | #Bitcoin and #cryptocurrency enthusiast \ud83d\ude80 Business TG: \u2018roverbusiness\u2019",
#                 "url": "https://t.co/g7uoel2n7C",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/g7uoel2n7C",
#                                 "expanded_url": "https://t.me/cryptorovertelegram",
#                                 "display_url": "t.me/cryptorovertel\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 263030,
#                 "friends_count": 338,
#                 "listed_count": 666,
#                 "created_at": "Sun Jan 24 16:50:08 +0000 2021",
#                 "favourites_count": 18533,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": true,
#                 "statuses_count": 12333,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1492942875373588490/GSC34oOF_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1492942875373588490/GSC34oOF_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1353384573435056128/1656685082",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 15,
#             "favorite_count": 158,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 15,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Fri Jul 01 18:24:47 +0000 2022",
#         "id": 1542937275268358144,
#         "id_str": "1542937275268358144",
#         "text": "RT @natbrunell: Imagine what the next ATH will feel like after getting through this bear market in #Bitcoin?",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Bitcoin",
#                     "indices": [
#                         99,
#                         107
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "natbrunell",
#                     "name": "Natalie Brunell",
#                     "id": 543483223,
#                     "id_str": "543483223",
#                     "indices": [
#                         3,
#                         14
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1219144670,
#             "id_str": "1219144670",
#             "name": "I LOVE APENFT",
#             "screen_name": "tkddnrdl5",
#             "location": "",
#             "description": "I LOVE APENFT",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 215,
#             "friends_count": 1227,
#             "listed_count": 9,
#             "created_at": "Mon Feb 25 15:57:31 +0000 2013",
#             "favourites_count": 4859,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 3015,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1433598226930626590/ZHeUU-GT_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1433598226930626590/ZHeUU-GT_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Fri Jul 01 04:20:17 +0000 2022",
#             "id": 1542724749880467456,
#             "id_str": "1542724749880467456",
#             "text": "Imagine what the next ATH will feel like after getting through this bear market in #Bitcoin?",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             83,
#                             91
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 543483223,
#                 "id_str": "543483223",
#                 "name": "Natalie Brunell",
#                 "screen_name": "natbrunell",
#                 "location": "No Financial Advice",
#                 "description": "Host of Coin Stories #Bitcoin podcast | Media Commentator | Host, @HardMoneyShow | Investor | Educator | Writer | Emmy Winning Journalist | 1st Generation \ud83c\uddfa\ud83c\uddf8",
#                 "url": "https://t.co/mz263rFKrp",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/mz263rFKrp",
#                                 "expanded_url": "http://www.talkingbitcoin.com",
#                                 "display_url": "talkingbitcoin.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 237875,
#                 "friends_count": 3902,
#                 "listed_count": 1371,
#                 "created_at": "Mon Apr 02 15:10:28 +0000 2012",
#                 "favourites_count": 12911,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 14170,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "291138",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1539217266608287748/chPRWZkW_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1539217266608287748/chPRWZkW_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/543483223/1649634522",
#                 "profile_link_color": "0084B4",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "C0DFEC",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 112,
#             "favorite_count": 1885,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 112,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Fri Jul 01 18:24:47 +0000 2022",
#         "id": 1542937274106667009,
#         "id_str": "1542937274106667009",
#         "text": "BlockFi, kripto borsas\u0131 FTX taraf\u0131ndan 240 milyon dolara sat\u0131n al\u0131nma teklifini kabul etti. -Axios\n\nBlockFi ayr\u0131ca\u2026 https://t.co/eollv0Ou6J",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/eollv0Ou6J",
#                     "expanded_url": "https://twitter.com/i/web/status/1542937274106667009",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         116,
#                         139
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "result_type": "recent",
#             "iso_language_code": "tr"
#         },
#         "source": "<a href=\"https://pipedream.com\" rel=\"nofollow\">Pipedream, Inc</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1384180046244376579,
#             "id_str": "1384180046244376579",
#             "name": "Kripto Haber \uea00",
#             "screen_name": "KriptoHaberApp",
#             "location": "\u0130stanbul",
#             "description": "Kripto Haber \u2022 #Bitcoin #Shib #Doge #MetaVerse ve #NFT haberlerine an\u0131nda ula\u015f\u0131n. Unutmay\u0131n K\u0131sa ve \u00d6z haber okumak istiyorsan\u0131z do\u011fru yerdesiniz.. \ud83d\udc68\u200d\ud83d\udcbb",
#             "url": "https://t.co/2R233do1g9",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/2R233do1g9",
#                             "expanded_url": "https://bio.link/kriptohaberapp",
#                             "display_url": "bio.link/kriptohaberapp",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 16518,
#             "friends_count": 1,
#             "listed_count": 40,
#             "created_at": "Mon Apr 19 16:20:31 +0000 2021",
#             "favourites_count": 10,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 5548,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1384180331624898561/yxAbSPY5_normal.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1384180331624898561/yxAbSPY5_normal.png",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1384180046244376579/1641907744",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "tr"
#     },
#     {
#         "created_at": "Fri Jul 01 18:24:46 +0000 2022",
#         "id": 1542937273091645441,
#         "id_str": "1542937273091645441",
#         "text": "RT @VeilleCyber3: #AI and #MachineLearning will move #financialservices industry forward\nhttps://t.co/7LDEGECq8A\n\n#cryptocurrencies #Machin\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "AI",
#                     "indices": [
#                         18,
#                         21
#                     ]
#                 },
#                 {
#                     "text": "MachineLearning",
#                     "indices": [
#                         26,
#                         42
#                     ]
#                 },
#                 {
#                     "text": "financialservices",
#                     "indices": [
#                         53,
#                         71
#                     ]
#                 },
#                 {
#                     "text": "cryptocurrencies",
#                     "indices": [
#                         114,
#                         131
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "VeilleCyber3",
#                     "name": "Cybers\u00e9curit\u00e9, IA, Metavers, Cryptomonnaies",
#                     "id": 1273173749492219905,
#                     "id_str": "1273173749492219905",
#                     "indices": [
#                         3,
#                         16
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/7LDEGECq8A",
#                     "expanded_url": "http://ow.ly/Jp1750JLmSr",
#                     "display_url": "ow.ly/Jp1750JLmSr",
#                     "indices": [
#                         89,
#                         112
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels\" rel=\"nofollow\">PythonRoboto</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1371551211351121920,
#             "id_str": "1371551211351121920",
#             "name": "Python Roboto",
#             "screen_name": "PythonRoboto",
#             "location": "",
#             "description": "Retweeting all things coding (with a focus on Python).  Use #python, #100DaysOfCode for retweet\n\nCreated by @MingjuRoberts",
#             "url": "https://t.co/XaBT4gNO1R",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/XaBT4gNO1R",
#                             "expanded_url": "https://tmdstudios.wordpress.com/py-learning-companion/",
#                             "display_url": "tmdstudios.wordpress.com/py-learning-co\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 2365,
#             "friends_count": 2,
#             "listed_count": 40,
#             "created_at": "Mon Mar 15 19:58:04 +0000 2021",
#             "favourites_count": 83,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 264753,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1371892796655861763/6t8UC_jf_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1371892796655861763/6t8UC_jf_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1371551211351121920/1615922194",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Fri Jul 01 18:20:02 +0000 2022",
#             "id": 1542936081364123650,
#             "id_str": "1542936081364123650",
#             "text": "#AI and #MachineLearning will move #financialservices industry forward\nhttps://t.co/7LDEGECq8A\n\n#cryptocurrencies\u2026 https://t.co/cNah9B4lw8",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "AI",
#                         "indices": [
#                             0,
#                             3
#                         ]
#                     },
#                     {
#                         "text": "MachineLearning",
#                         "indices": [
#                             8,
#                             24
#                         ]
#                     },
#                     {
#                         "text": "financialservices",
#                         "indices": [
#                             35,
#                             53
#                         ]
#                     },
#                     {
#                         "text": "cryptocurrencies",
#                         "indices": [
#                             96,
#                             113
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/7LDEGECq8A",
#                         "expanded_url": "http://ow.ly/Jp1750JLmSr",
#                         "display_url": "ow.ly/Jp1750JLmSr",
#                         "indices": [
#                             71,
#                             94
#                         ]
#                     },
#                     {
#                         "url": "https://t.co/cNah9B4lw8",
#                         "expanded_url": "https://twitter.com/i/web/status/1542936081364123650",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             115,
#                             138
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://www.hootsuite.com\" rel=\"nofollow\">Hootsuite Inc.</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1273173749492219905,
#                 "id_str": "1273173749492219905",
#                 "name": "Cybers\u00e9curit\u00e9, IA, Metavers, Cryptomonnaies",
#                 "screen_name": "VeilleCyber3",
#                 "location": "Paris",
#                 "description": "Top 10 Influencers #insurtech / #cybersecurity #Metaverse #AI #crypto #intelligenceartificielle #cybersecurite #bitcoin @Probe_IT_",
#                 "url": "https://t.co/yCUYTmGzZa",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/yCUYTmGzZa",
#                                 "expanded_url": "https://veille-cyber.com/",
#                                 "display_url": "veille-cyber.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2647,
#                 "friends_count": 149,
#                 "listed_count": 68,
#                 "created_at": "Wed Jun 17 08:41:18 +0000 2020",
#                 "favourites_count": 9196,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 14256,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1524765050124263426/qyqnDvVj_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1524765050124263426/qyqnDvVj_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1273173749492219905/1655198243",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 2,
#             "favorite_count": 2,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 2,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Fri Jul 01 18:24:46 +0000 2022",
#         "id": 1542937270264729600,
#         "id_str": "1542937270264729600",
#         "text": "@davidgokhshtein Only happening if people starts understanding #bitcoin \ud83e\udd72",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "bitcoin",
#                     "indices": [
#                         63,
#                         71
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "davidgokhshtein",
#                     "name": "David Gokhshtein @ Work",
#                     "id": 170049408,
#                     "id_str": "170049408",
#                     "indices": [
#                         0,
#                         16
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": 1542936137454477313,
#         "in_reply_to_status_id_str": "1542936137454477313",
#         "in_reply_to_user_id": 170049408,
#         "in_reply_to_user_id_str": "170049408",
#         "in_reply_to_screen_name": "davidgokhshtein",
#         "user": {
# ...
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1497065370053664771,
#             "id_str": "1497065370053664771",
#             "name": "Furkan Simsekler",
#             "screen_name": "FurkanSimsekler",
#             "location": "T\u00fcrkiye",
#             "description": "Ya oldu\u011fun gibi g\u00f6r\u00fcn ya da g\u00f6r\u00fcnd\u00fc\u011f\u00fcn gibi ol...\n \ud83c\udf89Airdrop ve \u00c7ekili\u015f Payla\u015f\u0131m Sayfas\u0131\ud83d\ude80\ud83d\udcaf\ud83d\udd25\ud83e\uddd0Takipte Kal\u0131n...",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 301,
#             "friends_count": 2380,
#             "listed_count": 1,
#             "created_at": "Fri Feb 25 04:26:47 +0000 2022",
#             "favourites_count": 26426,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 20687,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1516434413835411462/dCmM-Jyj_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1516434413835411462/dCmM-Jyj_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1497065370053664771/1650813458",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Fri Jul 01 14:36:31 +0000 2022",
#             "id": 1542879832111026177,
#             "id_str": "1542879832111026177",
#             "text": "Asgari \u00fccret ile 0.01685 #Bitcoin sat\u0131n alabilirsiniz \u2b50",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             25,
#                             33
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "result_type": "recent",
#                 "iso_language_code": "tr"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1442168795338973189,
#                 "id_str": "1442168795338973189",
#                 "name": "G\u00fcncel Kripto",
#                 "screen_name": "guncelkriptocom",
#                 "location": "T\u00fcrkiye",
#                 "description": "T\u00fcrkiye'de pop\u00fcler olmam\u0131\u015f yeni coin haberleri . #Bitcoin #Altcoin #DeFi #Blockchain\n#kripto #analiz $btc Telegram ; https://t.co/u57q3fVl3N",
#                 "url": "https://t.co/eoWAwtAyUv",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/eoWAwtAyUv",
#                                 "expanded_url": "https://www.guncelkripto.com",
#                                 "display_url": "guncelkripto.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/u57q3fVl3N",
#                                 "expanded_url": "https://t.me/guncelkriptoyayin",
#                                 "display_url": "t.me/guncelkriptoya\u2026",
#                                 "indices": [
#                                     117,
#                                     140
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 20436,
#                 "friends_count": 63,
#                 "listed_count": 12,
#                 "created_at": "Sun Sep 26 16:46:55 +0000 2021",
#                 "favourites_count": 2540,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 1979,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1462563055418675200/WapdsOgT_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1462563055418675200/WapdsOgT_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1442168795338973189/1656203372",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 18,
#             "favorite_count": 127,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "tr"
#         },
#         "is_quote_status": false,
#         "retweet_count": 18,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "tr"
#     },
#     {
#         "created_at": "Fri Jul 01 18:23:36 +0000 2022",
#         "id": 1542936976298369024,
#         "id_str": "1542936976298369024",
#         "text": "RT @Stephan_barker: 75% of people never think. \n15% think they think. \nOnly 5% actually think.\n\nI think those 5% are bitcoiners\n\n#Bitcoin",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Bitcoin",
#                     "indices": [
#                         129,
#                         137
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "Stephan_barker",
#                     "name": "Stephan Barker",
#                     "id": 50629885,
#                     "id_str": "50629885",
#                     "indices": [
#                         3,
#                         18
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 68532712,
#             "id_str": "68532712",
#             "name": "Ger\ud83c\udf1e",
#             "screen_name": "gH2O",
#             "location": "\ud83c\udf0e",
#             "description": "I'm a student of modern societal infrastructure; who loves music, nature, and #Bitcoin \ud83e\udde0s \ud83d\ude4f\ud83c\udffc. |All Tweets are my Timed Opinions & Never any Financial Advice|",
#             "url": "https://t.co/2ifJsH4HXG",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/2ifJsH4HXG",
#                             "expanded_url": "http://hope.com",
#                             "display_url": "hope.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1483,
#             "friends_count": 5003,
#             "listed_count": 9,
#             "created_at": "Mon Aug 24 22:45:40 +0000 2009",
#             "favourites_count": 91224,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 20055,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "9AE4E8",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1362880817236570114/2X2_umX6_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1362880817236570114/2X2_umX6_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/68532712/1608766715",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "BDDCAD",
#             "profile_sidebar_fill_color": "DDFFCC",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Fri Jul 01 10:52:05 +0000 2022",
#             "id": 1542823351437213697,
#             "id_str": "1542823351437213697",
#             "text": "75% of people never think. \n15% think they think. \nOnly 5% actually think.\n\nI think those 5% are bitcoiners\n\n#Bitcoin",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             109,
#                             117
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 50629885,
#                 "id_str": "50629885",
#                 "name": "Stephan Barker",
#                 "screen_name": "Stephan_barker",
#                 "location": "Pretoria, South Africa",
#                 "description": "Buy \u20bfitcoin\nSeek Christ\nDrink Coffee\nLift Weights\nRun a node\n\ud83c\uddff\ud83c\udde6\nStack some more sats",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 362,
#                 "friends_count": 668,
#                 "listed_count": 13,
#                 "created_at": "Thu Jun 25 12:22:01 +0000 2009",
#                 "favourites_count": 3150,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 2219,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "0099B9",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1445722239827996673/6V_geg5C_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1445722239827996673/6V_geg5C_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/50629885/1632852673",
#                 "profile_link_color": "0099B9",
#                 "profile_sidebar_border_color": "5ED4DC",
#                 "profile_sidebar_fill_color": "95E8EC",
#                 "profile_text_color": "3C3940",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 11,
#             "favorite_count": 70,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 11,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     }
# ]

# %%
# Check statuses.
t = statuses[0]

# Print the keys.
t.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
# Find the id.
print(t['id'])

# View the ouput in text.
print(t['text'])

# View entities.
t['entities']
# Out:
# 1542937287524245510
# Bad sheet #Bitcoin
# {'hashtags': [{'text': 'Bitcoin', 'indices': [10, 18]}],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': []}

# %%
# A simpler option is:

# Run a test with #Bitcoin.
bitcoin_tweets = twitter_api.search.tweets(q="#Bitcoin")

# View JSON output.
print(json.dumps(bitcoin_tweets, indent=4))
# Out:
# {
#     "statuses": [
#         {
#             "created_at": "Fri Jul 01 18:25:44 +0000 2022",
#             "id": 1542937512699731970,
#             "id_str": "1542937512699731970",
#             "text": "RT @intocryptoverse: 90D EMA of #Bitcoin fear and greed https://t.co/3z4xLoVKlH",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             32,
#                             40
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "intocryptoverse",
#                         "name": "Benjamin Cowen",
#                         "id": 943506806931734528,
#                         "id_str": "943506806931734528",
#                         "indices": [
#                             3,
#                             19
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1542921116146081795,
#                         "id_str": "1542921116146081795",
#                         "indices": [
#                             56,
#                             79
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                         "url": "https://t.co/3z4xLoVKlH",
#                         "display_url": "pic.twitter.com/3z4xLoVKlH",
#                         "expanded_url": "https://twitter.com/intocryptoverse/status/1542921119023468549/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "small": {
#                                 "w": 680,
#                                 "h": 334,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 589,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1005,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542921119023468549,
#                         "source_status_id_str": "1542921119023468549",
#                         "source_user_id": 943506806931734528,
#                         "source_user_id_str": "943506806931734528"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1542921116146081795,
#                         "id_str": "1542921116146081795",
#                         "indices": [
#                             56,
#                             79
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                         "url": "https://t.co/3z4xLoVKlH",
#                         "display_url": "pic.twitter.com/3z4xLoVKlH",
#                         "expanded_url": "https://twitter.com/intocryptoverse/status/1542921119023468549/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "small": {
#                                 "w": 680,
#                                 "h": 334,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 589,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1005,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542921119023468549,
#                         "source_status_id_str": "1542921119023468549",
#                         "source_user_id": 943506806931734528,
#                         "source_user_id_str": "943506806931734528"
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 855067179493998592,
#                 "id_str": "855067179493998592",
#                 "name": "wolfofethereum.eth \ud83d\udc2c\ud83c\udd99",
#                 "screen_name": "Crypto_Wolf_0f",
#                 "location": "",
#                 "description": "#Bitcoin is cool but #Ethereum is cool AF. 2016 Founder of #ETHEREUM CT 2020 Founder of #LUKSO CT #texturepunx enforcer $LYXe $500 SETH $25k Flippening2022 \ud83d\udc2c",
#                 "url": "https://t.co/lBosPi0q8Y",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/lBosPi0q8Y",
#                                 "expanded_url": "http://gitcoin.co/grants/386/wol",
#                                 "display_url": "gitcoin.co/grants/386/wol",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2507,
#                 "friends_count": 0,
#                 "listed_count": 0,
#                 "created_at": "Thu Apr 20 14:34:36 +0000 2017",
#                 "favourites_count": 77,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 72,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1542928528919957506/eW5uk90m_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1542928528919957506/eW5uk90m_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/855067179493998592/1656697803",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Fri Jul 01 17:20:35 +0000 2022",
#                 "id": 1542921119023468549,
#                 "id_str": "1542921119023468549",
#                 "text": "90D EMA of #Bitcoin fear and greed https://t.co/3z4xLoVKlH",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 11,
#                                 19
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1542921116146081795,
#                             "id_str": "1542921116146081795",
#                             "indices": [
#                                 35,
#                                 58
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                             "url": "https://t.co/3z4xLoVKlH",
#                             "display_url": "pic.twitter.com/3z4xLoVKlH",
#                             "expanded_url": "https://twitter.com/intocryptoverse/status/1542921119023468549/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "small": {
#                                     "w": 680,
#                                     "h": 334,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 589,
#                                     "resize": "fit"
#                                 },
#                                 "large": {
#                                     "w": 2048,
#                                     "h": 1005,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "id": 1542921116146081795,
#                             "id_str": "1542921116146081795",
#                             "indices": [
#                                 35,
#                                 58
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FWmOlJRWIAMUtvs.jpg",
#                             "url": "https://t.co/3z4xLoVKlH",
#                             "display_url": "pic.twitter.com/3z4xLoVKlH",
#                             "expanded_url": "https://twitter.com/intocryptoverse/status/1542921119023468549/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "small": {
#                                     "w": 680,
#                                     "h": 334,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 589,
#                                     "resize": "fit"
#                                 },
#                                 "large": {
#                                     "w": 2048,
#                                     "h": 1005,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://itunes.apple.com/us/app/twitter/id409789998?mt=12\" rel=\"nofollow\">Twitter for Mac</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 943506806931734528,
#                     "id_str": "943506806931734528",
#                     "name": "Benjamin Cowen",
#                     "screen_name": "intocryptoverse",
#                     "location": "",
#                     "description": "Crypto Quant. Analysis PhD Engineering\nhttps://t.co/9eWsnXQVCs",
#                     "url": "https://t.co/Llgs17EVN0",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/Llgs17EVN0",
#                                     "expanded_url": "https://intothecryptoverse.com/",
#                                     "display_url": "intothecryptoverse.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/9eWsnXQVCs",
#                                     "expanded_url": "https://www.youtube.com/channel/UCRvqjQPSeaWn-uEx-w0XOIg",
#                                     "display_url": "youtube.com/channel/UCRvqj\u2026",
#                                     "indices": [
#                                         39,
#                                         62
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 675940,
#                     "friends_count": 187,
#                     "listed_count": 4625,
#                     "created_at": "Wed Dec 20 15:42:07 +0000 2017",
#                     "favourites_count": 10667,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": false,
#                     "statuses_count": 10555,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1393293173854597120/t-KVh409_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1393293173854597120/t-KVh409_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/943506806931734528/1636665119",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": false,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 17,
#                 "favorite_count": 221,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 17,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Fri Jul 01 18:25:43 +0000 2022",
#             "id": 1542937509419687939,
#             "id_str": "1542937509419687939",
#             "text": "RT @saylor: If you love nothing, nothing will love you back. #Bitcoin",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             61,
#                             69
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "saylor",
#                         "name": "Michael Saylor\u26a1\ufe0f",
#                         "id": 244647486,
#                         "id_str": "244647486",
#                         "indices": [
#                             3,
#                             10
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1487817271733018627,
#                 "id_str": "1487817271733018627",
#                 "name": "Cryptodude101",
#                 "screen_name": "michaellilienf4",
#                 "location": "",
#                 "description": "#Buy Bitcoin",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 166,
#                 "friends_count": 97,
#                 "listed_count": 10,
#                 "created_at": "Sun Jan 30 15:57:59 +0000 2022",
#                 "favourites_count": 9680,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 5131,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1523284971263340545/aHuQDOPQ_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1523284971263340545/aHuQDOPQ_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1487817271733018627/1650830448",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Fri Jul 01 12:32:45 +0000 2022",
#                 "id": 1542848684068577283,
#                 "id_str": "1542848684068577283",
#                 "text": "If you love nothing, nothing will love you back. #Bitcoin",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 49,
#                                 57
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": []
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 244647486,
#                     "id_str": "244647486",
#                     "name": "Michael Saylor\u26a1\ufe0f",
#                     "screen_name": "saylor",
#                     "location": "Miami Beach, FL",
#                     "description": "$MSTR Founder & CEO | @MIT Aerospace | bio @ https://t.co/9Zlq0oHqyh | free education @ https://t.co/4L1s0iwzQ6 | #Bitcoin is https://t.co/ejezpjeUZ4 & https://t.co/SLbKcP1BnV. | All tweets are my own.",
#                     "url": "https://t.co/OgF8IgNiDo",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/OgF8IgNiDo",
#                                     "expanded_url": "https://microstrategy.com",
#                                     "display_url": "microstrategy.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/9Zlq0oHqyh",
#                                     "expanded_url": "http://michael.com",
#                                     "display_url": "michael.com",
#                                     "indices": [
#                                         45,
#                                         68
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/4L1s0iwzQ6",
#                                     "expanded_url": "http://saylor.org",
#                                     "display_url": "saylor.org",
#                                     "indices": [
#                                         88,
#                                         111
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/ejezpjeUZ4",
#                                     "expanded_url": "http://hope.com",
#                                     "display_url": "hope.com",
#                                     "indices": [
#                                         126,
#                                         149
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/SLbKcP1BnV",
#                                     "expanded_url": "http://strategy.com",
#                                     "display_url": "strategy.com",
#                                     "indices": [
#                                         152,
#                                         175
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2603079,
#                     "friends_count": 592,
#                     "listed_count": 15046,
#                     "created_at": "Sat Jan 29 20:11:04 +0000 2011",
#                     "favourites_count": 2742,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": true,
#                     "statuses_count": 3480,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "C0DEED",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1485632175932383235/8t0DGo6V_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1485632175932383235/8t0DGo6V_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/244647486/1606261344",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": false,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 1036,
#                 "favorite_count": 9638,
#                 "favorited": false,
#                 "retweeted": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 1036,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Fri Jul 01 18:25:42 +0000 2022",
#             "id": 1542937507158974470,
#             "id_str": "1542937507158974470",
#             "text": "RT @BTC_Archive: #Bitcoin is about to close  -40% in June \n- the worst month ever! \ud83e\udd28 https://t.co/rQ2JckE7rF",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             17,
#                             25
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "BTC_Archive",
#                         "name": "Bitcoin Archive \ud83d\uddc4\ud83d\ude80\ud83c\udf14",
#                         "id": 970994516357472257,
#                         "id_str": "970994516357472257",
#                         "indices": [
#                             3,
#                             15
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1542618807742636037,
#                         "id_str": "1542618807742636037",
#                         "indices": [
#                             85,
#                             108
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                         "url": "https://t.co/rQ2JckE7rF",
#                         "display_url": "pic.twitter.com/rQ2JckE7rF",
#                         "expanded_url": "https://twitter.com/BTC_Archive/status/1542619211272421377/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 602,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1028,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 341,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542619211272421377,
#                         "source_status_id_str": "1542619211272421377",
#                         "source_user_id": 970994516357472257,
#                         "source_user_id_str": "970994516357472257"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1542618807742636037,
#                         "id_str": "1542618807742636037",
#                         "indices": [
#                             85,
#                             108
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                         "url": "https://t.co/rQ2JckE7rF",
#                         "display_url": "pic.twitter.com/rQ2JckE7rF",
#                         "expanded_url": "https://twitter.com/BTC_Archive/status/1542619211272421377/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 602,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1028,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 341,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542619211272421377,
#                         "source_status_id_str": "1542619211272421377",
#                         "source_user_id": 970994516357472257,
#                         "source_user_id_str": "970994516357472257"
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 855067179493998592,
#                 "id_str": "855067179493998592",
#                 "name": "wolfofethereum.eth \ud83d\udc2c\ud83c\udd99",
#                 "screen_name": "Crypto_Wolf_0f",
#                 "location": "",
#                 "description": "#Bitcoin is cool but #Ethereum is cool AF. 2016 Founder of #ETHEREUM CT 2020 Founder of #LUKSO CT #texturepunx enforcer $LYXe $500 SETH $25k Flippening2022 \ud83d\udc2c",
#                 "url": "https://t.co/lBosPi0q8Y",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/lBosPi0q8Y",
#                                 "expanded_url": "http://gitcoin.co/grants/386/wol",
#                                 "display_url": "gitcoin.co/grants/386/wol",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2507,
#                 "friends_count": 0,
#                 "listed_count": 0,
#                 "created_at": "Thu Apr 20 14:34:36 +0000 2017",
#                 "favourites_count": 77,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 72,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1542928528919957506/eW5uk90m_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1542928528919957506/eW5uk90m_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/855067179493998592/1656697803",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Thu Jun 30 21:20:55 +0000 2022",
#                 "id": 1542619211272421377,
#                 "id_str": "1542619211272421377",
#                 "text": "#Bitcoin is about to close  -40% in June \n- the worst month ever! \ud83e\udd28 https://t.co/rQ2JckE7rF",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 0,
#                                 8
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1542618807742636037,
#                             "id_str": "1542618807742636037",
#                             "indices": [
#                                 68,
#                                 91
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                             "url": "https://t.co/rQ2JckE7rF",
#                             "display_url": "pic.twitter.com/rQ2JckE7rF",
#                             "expanded_url": "https://twitter.com/BTC_Archive/status/1542619211272421377/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 602,
#                                     "resize": "fit"
#                                 },
#                                 "large": {
#                                     "w": 2048,
#                                     "h": 1028,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 341,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "id": 1542618807742636037,
#                             "id_str": "1542618807742636037",
#                             "indices": [
#                                 68,
#                                 91
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FWh7oetWIAUuKFE.jpg",
#                             "url": "https://t.co/rQ2JckE7rF",
#                             "display_url": "pic.twitter.com/rQ2JckE7rF",
#                             "expanded_url": "https://twitter.com/BTC_Archive/status/1542619211272421377/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 602,
#                                     "resize": "fit"
#                                 },
#                                 "large": {
#                                     "w": 2048,
#                                     "h": 1028,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 341,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 970994516357472257,
#                     "id_str": "970994516357472257",
#                     "name": "Bitcoin Archive \ud83d\uddc4\ud83d\ude80\ud83c\udf14",
#                     "screen_name": "BTC_Archive",
#                     "location": "",
#                     "description": "#Bitcoin News, Insight & Commentary \ud83d\ude80\ud83c\udf14 \nYouTube: https://t.co/gbPLKireeT",
#                     "url": null,
#                     "entities": {
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/gbPLKireeT",
#                                     "expanded_url": "http://tinyurl.com/BTCArchiveYouTube",
#                                     "display_url": "tinyurl.com/BTCArchiveYouT\u2026",
#                                     "indices": [
#                                         49,
#                                         72
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 1092713,
#                     "friends_count": 544,
#                     "listed_count": 5849,
#                     "created_at": "Tue Mar 06 12:08:27 +0000 2018",
#                     "favourites_count": 138679,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 31898,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1523608991422722049/NnAUKAZ-_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1523608991422722049/NnAUKAZ-_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/970994516357472257/1613812203",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": false,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 914,
#                 "favorite_count": 5439,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 914,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Fri Jul 01 18:25:42 +0000 2022",
#             "id": 1542937507137978368,
#             "id_str": "1542937507137978368",
#             "text": "#Bitcoin &gt; Blockfi https://t.co/UKJHNpEgeE",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             0,
#                             8
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1542937195820077056,
#                         "id_str": "1542937195820077056",
#                         "indices": [
#                             22,
#                             45
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWmdNGuX0AAyFlv.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWmdNGuX0AAyFlv.jpg",
#                         "url": "https://t.co/UKJHNpEgeE",
#                         "display_url": "pic.twitter.com/UKJHNpEgeE",
#                         "expanded_url": "https://twitter.com/mcshane_writes/status/1542937507137978368/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 994,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
# ...
#                         "expanded_url": "https://twitter.com/mcshane_writes/status/1542834704801566720/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 600,
#                                 "h": 470,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 600,
#                                 "h": 470,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 600,
#                                 "h": 470,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             }
#                         },
#                         "source_status_id": 1542834704801566720,
#                         "source_status_id_str": "1542834704801566720",
#                         "source_user_id": 1249174530930638848,
#                         "source_user_id_str": "1249174530930638848"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1542834611373359104,
#                         "id_str": "1542834611373359104",
#                         "indices": [
#                             56,
#                             79
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWk_554WQAAgds1.png",
#                         "media_url_https": "https://pbs.twimg.com/media/FWk_554WQAAgds1.png",
#                         "url": "https://t.co/AyM9BnU1Hh",
#                         "display_url": "pic.twitter.com/AyM9BnU1Hh",
#                         "expanded_url": "https://twitter.com/mcshane_writes/status/1542834704801566720/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 600,
#                                 "h": 470,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 600,
#                                 "h": 470,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 600,
#                                 "h": 470,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             }
#                         },
#                         "source_status_id": 1542834704801566720,
#                         "source_status_id_str": "1542834704801566720",
#                         "source_user_id": 1249174530930638848,
#                         "source_user_id_str": "1249174530930638848"
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 855067179493998592,
#                 "id_str": "855067179493998592",
#                 "name": "wolfofethereum.eth \ud83d\udc2c\ud83c\udd99",
#                 "screen_name": "Crypto_Wolf_0f",
#                 "location": "",
#                 "description": "#Bitcoin is cool but #Ethereum is cool AF. 2016 Founder of #ETHEREUM CT 2020 Founder of #LUKSO CT #texturepunx enforcer $LYXe $500 SETH $25k Flippening2022 \ud83d\udc2c",
#                 "url": "https://t.co/lBosPi0q8Y",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/lBosPi0q8Y",
#                                 "expanded_url": "http://gitcoin.co/grants/386/wol",
#                                 "display_url": "gitcoin.co/grants/386/wol",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2507,
#                 "friends_count": 0,
#                 "listed_count": 0,
#                 "created_at": "Thu Apr 20 14:34:36 +0000 2017",
#                 "favourites_count": 77,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 72,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1542928528919957506/eW5uk90m_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1542928528919957506/eW5uk90m_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/855067179493998592/1656697803",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Fri Jul 01 11:37:12 +0000 2022",
#                 "id": 1542834704801566720,
#                 "id_str": "1542834704801566720",
#                 "text": "Learn #Bitcoin for a stronger hodl. https://t.co/AyM9BnU1Hh",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 6,
#                                 14
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1542834611373359104,
#                             "id_str": "1542834611373359104",
#                             "indices": [
#                                 36,
#                                 59
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWk_554WQAAgds1.png",
#                             "media_url_https": "https://pbs.twimg.com/media/FWk_554WQAAgds1.png",
#                             "url": "https://t.co/AyM9BnU1Hh",
#                             "display_url": "pic.twitter.com/AyM9BnU1Hh",
#                             "expanded_url": "https://twitter.com/mcshane_writes/status/1542834704801566720/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "large": {
#                                     "w": 600,
#                                     "h": 470,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 600,
#                                     "h": 470,
#                                     "resize": "fit"
#                                 },
#                                 "medium": {
#                                     "w": 600,
#                                     "h": 470,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "id": 1542834611373359104,
#                             "id_str": "1542834611373359104",
#                             "indices": [
#                                 36,
#                                 59
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWk_554WQAAgds1.png",
#                             "media_url_https": "https://pbs.twimg.com/media/FWk_554WQAAgds1.png",
#                             "url": "https://t.co/AyM9BnU1Hh",
#                             "display_url": "pic.twitter.com/AyM9BnU1Hh",
#                             "expanded_url": "https://twitter.com/mcshane_writes/status/1542834704801566720/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "large": {
#                                     "w": 600,
#                                     "h": 470,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 600,
#                                     "h": 470,
#                                     "resize": "fit"
#                                 },
#                                 "medium": {
#                                     "w": 600,
#                                     "h": 470,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1249174530930638848,
#                     "id_str": "1249174530930638848",
#                     "name": "McShane",
#                     "screen_name": "mcshane_writes",
#                     "location": "\u20bfunker ",
#                     "description": "#Bitcoin",
#                     "url": "https://t.co/bG8pbG6KBT",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/bG8pbG6KBT",
#                                     "expanded_url": "https://linktr.ee/alexmcshane",
#                                     "display_url": "linktr.ee/alexmcshane",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 22209,
#                     "friends_count": 854,
#                     "listed_count": 170,
#                     "created_at": "Sun Apr 12 03:17:31 +0000 2020",
#                     "favourites_count": 27384,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": true,
#                     "statuses_count": 188,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1533235049285443585/ceAY6YmF_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1533235049285443585/ceAY6YmF_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1249174530930638848/1655134597",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 133,
#                 "favorite_count": 986,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 133,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         }
#     ],
#     "search_metadata": {
#         "completed_in": 0.098,
#         "max_id": 1542937512699731970,
#         "max_id_str": "1542937512699731970",
#         "next_results": "?max_id=1542937485046579199&q=%23Bitcoin&include_entities=1",
#         "query": "%23Bitcoin",
#         "refresh_url": "?since_id=1542937512699731970&q=%23Bitcoin&include_entities=1",
#         "count": 15,
#         "since_id": 0,
#         "since_id_str": "0"
#     }
# }
